# %%
from scipy.io import loadmat
import pandas as pd
from scipy.io import loadmat
import numpy as np
import warnings  
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectFromModel,f_classif
from sklearn.feature_selection import VarianceThreshold
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import r2_score, explained_variance_score,f1_score,precision_score,recall_score, confusion_matrix, accuracy_score, classification_report, log_loss
data = loadmat('ERP.mat')

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue Sep 14 14:11:37 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Fs': array([[256]], dtype=uint16),
#  'N': array([[39]], dtype=uint8),
#  'Norm01': array([[(array([[[  14.0500288 ,    4.5982728 ,  -37.07828903, ...,
#                    -31.54125404,  -45.77269363,   11.13742828],
#                  [  14.37486935,   -2.39312029,  -35.50805283, ...,
#                    -25.14631844,  -40.85920715,   13.3809576 ],
#                  [  14.53674126,   -7.35386992,  -34.48316193, ...,
#                    -19.15168762,  -36.68637466,   14.71709633],
#                  ...,
#                  [ 101.87356567,   -0.4431186 ,   42.60646057, ...,
#                      7.3546586 ,  -51.40280533, -106.72655487],
#                  [  95.96482086,   -7.13801193,   43.72925949, ...,
#                     11.55973339,  -44.5174675 , -109.85425568],
# ...

# %% [markdown]
#  ### features

# %%
featuredictn={}
for trial in range(1,40):
    locals()['featuredictn{0}'.format(trial)] = {}
    locals()['featuredictn{0}'.format(trial)]['max_ampfz1']=data['max_ampdfz1_%s' %trial].tolist()
featuredictn1
# Out:
# {'max_ampfz1': [[7.795793533325195]]}

# %%
featuredictn={}
for trial in range(1,40):
    locals()['featuredictn{0}'.format(trial)] = {}
    locals()['featuredictn{0}'.format(trial)]['max_ampfz1']=data['max_ampdfz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz1']=data['max_ampdcz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz1']=data['max_ampdpz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampfz2']=data['max_ampdfz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz2']=data['max_ampdcz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz2']=data['max_ampdpz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampfz3']=data['max_ampdfz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz3']=data['max_ampdcz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz3']=data['max_ampdpz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampfz4']=data['max_ampdfz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz4']=data['max_ampdcz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz4']=data['max_ampdpz4_%s' %trial].tolist()
    
    
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz1']=data['latency_maxdfz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz1']=data['latency_maxdcz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz1']=data['latency_maxdpz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz2']=data['latency_maxdfz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz2']=data['latency_maxdcz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz2']=data['latency_maxdpz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz3']=data['latency_maxdfz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz3']=data['latency_maxdcz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz3']=data['latency_maxdpz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz4']=data['latency_maxdfz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz4']=data['latency_maxdcz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz4']=data['latency_maxdpz4_%s' %trial].tolist()
    
    locals()['distractor_df_{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{0}'.format(trial)].items()]))
    locals()['distractor_df_{0}'.format(trial)] = locals()['distractor_df_{0}'.format(trial)].fillna(0)
   
print(featuredictn1)
distractor_df_3.shape
# Out:
# {'max_ampfz1': [[7.795793533325195]], 'max_ampcz1': [[8.907994270324707]], 'max_amppz1': [[9.712512016296387]], 'max_ampfz2': [[22.64569854736328]], 'max_ampcz2': [[23.34684944152832]], 'max_amppz2': [[18.4317626953125]], 'max_ampfz3': [[7.1403608322143555]], 'max_ampcz3': [[23.34684944152832]], 'max_amppz3': [[18.4317626953125]], 'max_ampfz4': [[30.00792121887207]], 'max_ampcz4': [[23.815147399902344]], 'max_amppz4': [[24.5632266998291]], 'latency_maxfz1': [[0.13984375]], 'latency_maxcz1': [[0.11249999999999999]], 'latency_maxpz1': [[0.10859374999999999]], 'latency_maxfz2': [[0.21796875]], 'latency_maxcz2': [[0.2140625]], 'latency_maxpz2': [[0.19453125]], 'latency_maxfz3': [[0.1828125]], 'latency_maxcz3': [[0.2140625]], 'latency_maxpz3': [[0.19453125]], 'latency_maxfz4': [[0.35468750000000004]], 'latency_maxcz4': [[0.35468750000000004]], 'latency_maxpz4': [[0.44453125000000004]]}
# ...

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for trial in range(1,41):
    locals()['featuredicttarget{0}'.format(trial)] = {}
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz1' ]=data['max_amptfz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz1' ]=data['max_amptcz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz1' ]=data['max_amptpz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz2' ]=data['max_amptfz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz2' ]=data['max_amptcz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz2' ]=data['max_amptpz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz3' ]=data['max_amptfz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz3' ]=data['max_amptcz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz3' ]=data['max_amptpz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz4' ]=data['max_amptfz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz4' ]=data['max_amptcz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz4' ]=data['max_amptpz4_%s' %trial].tolist()
    
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz1' ]=data['latency_maxtfz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz1' ]=data['latency_maxtcz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz1' ]=data['latency_maxtpz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz2' ]=data['latency_maxtfz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz2' ]=data['latency_maxtcz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz2' ]=data['latency_maxtpz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz3' ]=data['latency_maxtfz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz3' ]=data['latency_maxtcz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz3' ]=data['latency_maxtpz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz4' ]=data['latency_maxtfz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz4' ]=data['latency_maxtcz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz4' ]=data['latency_maxtpz4_%s' %trial].tolist()
    
    locals()['target_df_{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{0}'.format(trial)].items()]))
    locals()['target_df_{0}'.format(trial)] = locals()['target_df_{0}'.format(trial)].fillna(0)
   

target_df_3.shape
# Out:
# C:\Users\kaila\AppData\Local\Temp\ipykernel_16640\3165049885.py:30: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{0}'.format(trial)].items()]))
# (1, 24)

# %%
dfs = []
for trial in range(1,40):
    #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
    dfs.append(locals()['distractor_df_{0}'.format(trial)] )
df_distractor=pd.concat(dfs,ignore_index=True)
df_distractor=df_distractor.fillna(0)
df_distractor
# Out:
#     max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1     4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2     0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3     6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4    82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# 5    24.367966    8.615045   15.267007   -6.827663   10.037431   16.425827
# 6    24.993153    0.000000    0.000000   23.367960   35.638844   39.040798
# 7    24.090633   10.899263    0.000000   21.696728   30.748428   29.677572
# 8    17.241610    6.370624    5.887115   12.657302    4.200091    4.653949
# 9    37.571991   36.702454   37.202721   67.619743   45.216702   23.946779
# 10   43.604034  -20.587233   -7.886579   37.935158   27.218611   36.348751
# ...

# %%
df_distractor['label']=0

# %%
dfst = []
for trial in range(1,41):
    #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
    dfst.append(locals()['target_df_{0}'.format(trial)] )
df_target=pd.concat(dfst,ignore_index=True)
df_target=df_target.fillna(0)
df_target
# Out:
#     max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0    34.009487    0.000000    0.000000   23.372818   21.690861   12.316854
# 1     0.000000   50.831646   31.864912   22.725946   25.759485   20.879736
# 2    32.939423   -2.582398   20.934744    0.855119   -3.710462   20.934744
# 3     8.476193    2.194859   20.437674   32.597767   35.201843   36.077045
# 4    23.039204   -0.402013   11.612050   -9.358294    1.014682   27.943575
# 5   -12.704741   47.134747   35.620075   69.638527   68.062187   69.522003
# 6     0.000000   23.942337   15.505064   17.350670   19.105309   21.585720
# 7    21.818045   11.006424    7.446183   26.526321   16.799372   14.259039
# 8     2.262337   24.792761    0.000000   25.278164   28.445833   30.600721
# 9    15.910458    7.164993   21.616575   23.532854   24.184233   26.153637
# 10   28.078972   34.469048   25.439255   40.578072   49.751095   43.368362
# ...

# %%
df_target['label']=1

# %%
df=pd.concat([df_distractor, df_target] , ignore_index=True)
df=df.fillna(0)
df
# Out:
#     max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1     4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2     0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3     6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4    82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ..         ...         ...         ...         ...         ...         ...
# 74   69.807785  -33.468628  -15.768987  -53.400166  -23.327644  -17.536926
# 75   16.046841   39.495949   40.261089   32.761272   39.495949   40.261089
# 76   22.748463   -5.364698    2.910731    0.971191    1.619322    4.721009
# 77   42.142635    0.000000   17.829313   36.255394   31.207058   17.829313
# 78   83.967087  -18.572851   18.155128  -60.144196   25.507830   23.010870
#
# ...

# %%
#new code

# %%
X = df.loc[:, ~df.columns.isin(['label'])]
y = df['label']

# %%
print(X.mean())
# Out:
# max_ampfz1        25.394816
# max_ampcz1        10.465078
# max_amppz1        12.876454
# max_ampfz2        26.617717
# max_ampcz2        26.714055
# max_amppz2        27.303750
# max_ampfz3        18.046117
# max_ampcz3        26.733490
# max_amppz3        29.144713
# max_ampfz4        30.224929
# max_ampcz4        29.412819
# max_amppz4        33.585882
# latency_maxfz1     0.099970
# latency_maxcz1     0.084187
# latency_maxpz1     0.082338
# latency_maxfz2     0.182367
# latency_maxcz2     0.185532
# latency_maxpz2     0.186917
# latency_maxfz3     0.230380
# latency_maxcz3     0.215150
# latency_maxpz3     0.220787
# latency_maxfz4     0.351770
# latency_maxcz4     0.353748
# latency_maxpz4     0.361808
# dtype: float64

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA()),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X, y, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
normacc=mean(scores['test_accuracy'])
print(mean(scores['test_accuracy']))

print(std(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(std(scores['test_sensitivity']))
print(mean(scores['test_specificity']))
print(std(scores['test_sensitivity']))
# Out:
# 0.6589285714285714
# 0.1235760734056854
# 0.675
# 0.25124689052802224
# 0.6333333333333333
# 0.25124689052802224

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA()),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space1 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                
                ]




search_space2 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
               
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space3 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space4 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
               
                ]

search_space5 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)


scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf1=GridSearchCV(pipe, search_space1, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf2=GridSearchCV(pipe, search_space2, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf3=GridSearchCV(pipe, search_space3, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf4=GridSearchCV(pipe, search_space4, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf5=GridSearchCV(pipe, search_space5, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores1 = cross_validate(clf1, X, y, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores2 = cross_validate(clf2, X, y, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores3 = cross_validate(clf3, X, y, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores4 = cross_validate(clf4, X, y, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores5 = cross_validate(clf5, X, y, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
print('Logistic Regression accuracy', mean(scores1['test_accuracy']), 'standard deviation', std(scores1['test_accuracy']))
print('Logistic Regression sensitivity ',mean(scores1['test_sensitivity']), 'standard deviation', std(scores1['test_sensitivity'])  )
print('Logistic Regression specificity',mean(scores1['test_specificity']) , 'standard deviation', std(scores1['test_specificity']))

print('\n')

print('Random Forest Classifier accuracy',mean(scores2['test_accuracy']), 'standard deviation', std(scores2['test_accuracy']))
print('Random Forest Classifier sensitivity ',mean(scores2['test_sensitivity']),'standard deviation', std(scores2['test_sensitivity']))
print('Random Forest Classifier specificity',mean(scores2['test_specificity']),'standard deviation', std(scores2['test_specificity']))

print('\n')
print('Decision Tree Classifier accuracy',mean(scores3['test_accuracy']),'standard deviation', std(scores3['test_accuracy']))
print('Decision Tree Classifier sensitivity',mean(scores3['test_sensitivity']),'standard deviation', std(scores3['test_sensitivity']))
print('Decision Tree Classifier specificity',mean(scores3['test_specificity']),'standard deviation', std(scores3['test_specificity']))
print('\n')

print('KNeighborsClassifier accuracy',mean(scores4['test_accuracy']),'standard deviation', std(scores4['test_accuracy']))
print('KNeighborsClassifier sensitivity',mean(scores4['test_sensitivity']),'standard deviation', std(scores4['test_sensitivity']))
print('KNeighborsClassifier specificity',mean(scores4['test_specificity']),'standard deviation', std(scores4['test_specificity']))

print('\n')
print('SVM accuracy',mean(scores5['test_accuracy']),'standard deviation', std(scores5['test_accuracy']))
print('SVM sensitivity',mean(scores5['test_sensitivity']),'standard deviation', std(scores5['test_sensitivity']))
print('SVM specificity',mean(scores5['test_specificity']),'standard deviation', std(scores5['test_specificity']))
# Out:
# Logistic Regression accuracy 0.6196428571428572 standard deviation 0.13787055819255442
# Logistic Regression sensitivity  0.6 standard deviation 0.2
# Logistic Regression specificity 0.6333333333333333 standard deviation 0.29154759474226505
#
#
# Random Forest Classifier accuracy 0.6946428571428571 standard deviation 0.14295755399732454
# Random Forest Classifier sensitivity  0.675 standard deviation 0.19525624189766635
# Random Forest Classifier specificity 0.7083333333333333 standard deviation 0.2304886114323222
#
#
# Decision Tree Classifier accuracy 0.5553571428571429 standard deviation 0.13326023719146884
# Decision Tree Classifier sensitivity 0.575 standard deviation 0.225
# Decision Tree Classifier specificity 0.5333333333333333 standard deviation 0.19790570145063194
#
#
# KNeighborsClassifier accuracy 0.5553571428571429 standard deviation 0.15494609003239332
# KNeighborsClassifier sensitivity 0.525 standard deviation 0.2358495283014151
# ...

# %%
#clf.best_estimator_

# %%
#clf.best_score_

# %%
###old

# %%
normsub=mean(scores['test_accuracy'])
result=pd.DataFrame([['for single normal subject',normacc ]],columns=['subjecttype','Accuracy'])
result
# Out:
#                  subjecttype  Accuracy
# 0  for single normal subject  0.658929

# %% [markdown]
# ### for group of 10 normal subject

# %%
datagroup = loadmat('ERPfeaturegroup.mat')

# %%
datagroup ['latency_maxtcz410_2']
# Out:
# array([[0.29609375]])

# %% [markdown]
# ### feature

# %%
featuredictn={}
for sub in range(1,11):
    if sub==1: 
        trials=39 
    elif sub==2:
         trials=33
    elif sub==3:
         trials=35
    elif sub==4:
         trials=32
    elif sub==5:
         trials=37
    elif sub==6:
         trials=36
    elif sub==7:
         trials=23
    elif sub==8:
         trials=31
    elif sub==9:
         trials=33
    elif sub==10:
         trials=36

     
    for trial in range(1,trials+1):
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)] = {}
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz1']=datagroup['max_ampdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz1']=datagroup['max_ampdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz1']=datagroup['max_ampdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz2']=datagroup['max_ampdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz2']=datagroup['max_ampdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz2']=datagroup['max_ampdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz3']=datagroup['max_ampdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz3']=datagroup['max_ampdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz3']=datagroup['max_ampdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz4']=datagroup['max_ampdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz4']=datagroup['max_ampdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz4']=datagroup['max_ampdpz4%s_%s' %(sub ,trial)].tolist()


        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz1']=datagroup['latency_maxdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz1']=datagroup['latency_maxdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz1']=datagroup['latency_maxdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz2']=datagroup['latency_maxdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz2']=datagroup['latency_maxdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz2']=datagroup['latency_maxdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz3']=datagroup['latency_maxdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz3']=datagroup['latency_maxdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz3']=datagroup['latency_maxdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz4']=datagroup['latency_maxdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz4']=datagroup['latency_maxdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz4']=datagroup['latency_maxdpz4%s_%s' %(sub ,trial)].tolist()

        locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
        locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)] = locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)].fillna(0)

        
        
distractor_df_3_20.shape
# Out:
# <ipython-input-21-cfe1daeb63d2>:54: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
# (1, 24)

# %%
dfsgroup = []
for sub in range(1,11):
    if sub==1: 
        trials=39 
    elif sub==2:
         trials=33
    elif sub==3:
         trials=35
    elif sub==4:
         trials=32
    elif sub==5:
         trials=37
    elif sub==6:
         trials=36
    elif sub==7:
         trials=23
    elif sub==8:
         trials=31
    elif sub==9:
         trials=33
    elif sub==10:
         trials=36

    
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfsgroup.append(locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)] )
        #print(locals()['distractor_df_{0}_{0}'.format(sub,trial)])
        #locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]
    
df_distractorgroup=pd.concat(dfsgroup,ignore_index=True)
df_distractorgroup=df_distractorgroup.fillna(0)
df_distractorgroup
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1      4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2      0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3      6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4     82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ..          ...         ...         ...         ...         ...         ...
# 330   23.733706    0.000000  -14.775169   -1.718373   -3.377303   -1.999214
# 331   24.267157   -7.477717   -3.428447   16.919199    9.525473    9.857184
# 332   12.260180   -3.831869    1.675532   -9.201835   -4.775925    6.510189
# 333   30.112387   26.845972   29.674942   -1.680187   26.845972   29.674942
# 334   77.326561    0.000000   -1.894091  -73.999763  -38.746983   -6.437190
#
# ...

# %%
df_distractorgroup['label']=0

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for sub in range(1,11):
    if sub==1: 
        trials=40 
    elif sub==2:
         trials=36
    elif sub==3:
         trials=35
    elif sub==4:
         trials=36
    elif sub==5:
         trials=35
    elif sub==6:
         trials=31
    elif sub==7:
         trials=29
    elif sub==8:
         trials=29
    elif sub==9:
         trials=37
    elif sub==10:
         trials=34
     
    for trial in range(1,trials+1):
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)] = {}
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz1' ]=datagroup['max_amptfz1%s_%s' %(sub,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz1' ]=datagroup['max_amptcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz1' ]=datagroup['max_amptpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz2' ]=datagroup['max_amptfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz2' ]=datagroup['max_amptcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz2' ]=datagroup['max_amptpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz3' ]=datagroup['max_amptfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz3' ]=datagroup['max_amptcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz3' ]=datagroup['max_amptpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz4' ]=datagroup['max_amptfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz4' ]=datagroup['max_amptcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz4' ]=datagroup['max_amptpz4%s_%s' %(sub ,trial)].tolist()

        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz1' ]=datagroup['latency_maxtfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz1' ]=datagroup['latency_maxtcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz1' ]=datagroup['latency_maxtpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz2' ]=datagroup['latency_maxtfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz2' ]=datagroup['latency_maxtcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz2' ]=datagroup['latency_maxtpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz3' ]=datagroup['latency_maxtfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz3' ]=datagroup['latency_maxtcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz3' ]=datagroup['latency_maxtpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz4' ]=datagroup['latency_maxtfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz4' ]=datagroup['latency_maxtcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz4' ]=datagroup['latency_maxtpz4%s_%s' %(sub ,trial)].tolist()

        locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
        locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)] = locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)].fillna(0)


target_df_3_3.shape
# Out:
# <ipython-input-24-20ed4ed7c00b>:52: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
# (1, 24)

# %%
dfstgroup = []
for sub in range(1,11):
    if sub==1: 
        trials=40 
    elif sub==2:
         trials=36
    elif sub==3:
         trials=35
    elif sub==4:
         trials=36
    elif sub==5:
         trials=35
    elif sub==6:
         trials=31
    elif sub==7:
         trials=29
    elif sub==8:
         trials=29
    elif sub==9:
         trials=37
    elif sub==10:
         trials=34
     
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfstgroup.append(locals()['target_df_{s}_{t}'.format(s=sub,t=trial)] )
df_targetgroup=pd.concat(dfstgroup,ignore_index=True)
df_targetgroup=df_targetgroup.fillna(0)
df_targetgroup
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     34.009487    0.000000    0.000000   23.372818   21.690861   12.316854
# 1      0.000000   50.831646   31.864912   22.725946   25.759485   20.879736
# 2     32.939423   -2.582398   20.934744    0.855119   -3.710462   20.934744
# 3      7.605074    2.194859   20.437674   32.597767   35.201843   36.077045
# 4     23.039204   -0.402013   -1.437285   -9.358294    1.014682   27.943575
# ..          ...         ...         ...         ...         ...         ...
# 337   19.451349   -6.692491   -5.892643  -15.260897  -13.778296  -18.184422
# 338   55.426968  -31.942610   -1.898978  -20.591724   -6.483331    5.361621
# 339    0.000000   48.270428   24.624529   28.768499   37.608406   24.624529
# 340    0.117385   12.093614   27.237724   14.355549   12.093614   27.237724
# 341   12.605641    1.477478    6.617091    3.597151   -2.584366    6.696667
#
# ...

# %%
df_targetgroup['label']=1

# %%
df_group=pd.concat([df_distractorgroup, df_targetgroup] , ignore_index=True)
df_group=df_group.fillna(0)
df_group
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1      4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2      0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3      6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4     82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ..          ...         ...         ...         ...         ...         ...
# 672   19.451349   -6.692491   -5.892643  -15.260897  -13.778296  -18.184422
# 673   55.426968  -31.942610   -1.898978  -20.591724   -6.483331    5.361621
# 674    0.000000   48.270428   24.624529   28.768499   37.608406   24.624529
# 675    0.117385   12.093614   27.237724   14.355549   12.093614   27.237724
# 676   12.605641    1.477478    6.617091    3.597151   -2.584366    6.696667
#
# ...

# %%
X_group = df_group.loc[:, ~df_group.columns.isin(['label'])]
y_group = df_group['label']

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA()),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X_group, y_group, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
print(mean(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(mean(scores['test_specificity']))


print(std(scores['test_accuracy']))
print(std(scores['test_sensitivity']))
print(std(scores['test_specificity']))
# Out:
# 0.5452589991220369
# 0.5323529411764706
# 0.5585561497326204
# 0.06531935022711496
# 0.05190699912490294
# 0.09557513549301938

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space1 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                
                ]




search_space2 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
               
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space3 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space4 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
               
                ]

search_space5 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)


scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}

clf1=GridSearchCV(pipe, search_space1, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf2=GridSearchCV(pipe, search_space2, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf3=GridSearchCV(pipe, search_space3, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf4=GridSearchCV(pipe, search_space4, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf5=GridSearchCV(pipe, search_space5, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)


#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores1 = cross_validate(clf1, X_group, y_group, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores2 = cross_validate(clf2, X_group, y_group, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores3 = cross_validate(clf3, X_group, y_group, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores4 = cross_validate(clf4, X_group, y_group, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores5 = cross_validate(clf5, X_group, y_group, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)

print('Logistic Regression accuracy', mean(scores1['test_accuracy']), 'standard deviation', std(scores1['test_accuracy']))
print('Logistic Regression sensitivity ',mean(scores1['test_sensitivity']), 'standard deviation', std(scores1['test_sensitivity'])  )
print('Logistic Regression specificity',mean(scores1['test_specificity']) , 'standard deviation', std(scores1['test_specificity']))

print('\n')

print('Random Forest Classifier accuracy',mean(scores2['test_accuracy']), 'standard deviation', std(scores2['test_accuracy']))
print('Random Forest Classifier sensitivity ',mean(scores2['test_sensitivity']),'standard deviation', std(scores2['test_sensitivity']))
print('Random Forest Classifier specificity',mean(scores2['test_specificity']),'standard deviation', std(scores2['test_specificity']))

print('\n')
print('Decision Tree Classifier accuracy',mean(scores3['test_accuracy']),'standard deviation', std(scores3['test_accuracy']))
print('Decision Tree Classifier sensitivity',mean(scores3['test_sensitivity']),'standard deviation', std(scores3['test_sensitivity']))
print('Decision Tree Classifier specificity',mean(scores3['test_specificity']),'standard deviation', std(scores3['test_specificity']))
print('\n')

print('KNeighborsClassifier accuracy',mean(scores4['test_accuracy']),'standard deviation', std(scores4['test_accuracy']))
print('KNeighborsClassifier sensitivity',mean(scores4['test_sensitivity']),'standard deviation', std(scores4['test_sensitivity']))
print('KNeighborsClassifier specificity',mean(scores4['test_specificity']),'standard deviation', std(scores4['test_specificity']))

print('\n')
print('SVM accuracy',mean(scores5['test_accuracy']),'standard deviation', std(scores5['test_accuracy']))
print('SVM sensitivity',mean(scores5['test_sensitivity']),'standard deviation', std(scores5['test_sensitivity']))
print('SVM specificity',mean(scores5['test_specificity']),'standard deviation', std(scores5['test_specificity']))
# Out:
# Logistic Regression accuracy 0.5628182616330115 standard deviation 0.07431283667672844
# Logistic Regression sensitivity  0.5847058823529413 standard deviation 0.10196003016312351
# Logistic Regression specificity 0.5406417112299466 standard deviation 0.08521282193148519
#
#
# Random Forest Classifier accuracy 0.5717076382791924 standard deviation 0.04966083094964436
# Random Forest Classifier sensitivity  0.5700840336134453 standard deviation 0.06443926298852763
# Random Forest Classifier specificity 0.5731729055258468 standard deviation 0.06367960154246095
#
#
# Decision Tree Classifier accuracy 0.5717076382791924 standard deviation 0.0580232546827097
# Decision Tree Classifier sensitivity 0.584453781512605 standard deviation 0.060261241878934675
# Decision Tree Classifier specificity 0.55873440285205 standard deviation 0.10331260014188276
#
#
# KNeighborsClassifier accuracy 0.5643546971027217 standard deviation 0.04835983159768404
# ...

# %%
LinearSVC()
# Out:
# LinearSVC()

# %%
#normsubgroup=mean(scores1['test_accuracy'])
normgroupacc=mean(scores['test_accuracy'])
resultsubgroup=pd.DataFrame([['for group of 10 normal subject',normgroupacc ]],columns=['subjecttype','Accuracy'])
result=result.append(resultsubgroup,ignore_index=True)
result
# Out:
#                       subjecttype  Accuracy
# 0       for single normal subject  0.658929
# 1  for group of 10 normal subject  0.545259

# %% [markdown]
# ### for single schizo subject

# %%
dataschizo = loadmat('ERPschizo.mat')

# %%
featuredictn={}
for trial in range(1,38):
    locals()['featuredictn{0}'.format(trial)] = {}
    locals()['featuredictn{0}'.format(trial)]['max_ampfz1']=dataschizo['max_ampdfz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz1']=dataschizo['max_ampdcz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz1']=dataschizo['max_ampdpz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampfz2']=dataschizo['max_ampdfz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz2']=dataschizo['max_ampdcz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz2']=dataschizo['max_ampdpz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampfz3']=dataschizo['max_ampdfz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz3']=dataschizo['max_ampdcz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz3']=dataschizo['max_ampdpz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampfz4']=dataschizo['max_ampdfz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_ampcz4']=dataschizo['max_ampdcz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['max_amppz4']=dataschizo['max_ampdpz4_%s' %trial].tolist()
    
    
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz1']=dataschizo['latency_maxdfz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz1']=dataschizo['latency_maxdcz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz1']=dataschizo['latency_maxdpz1_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz2']=dataschizo['latency_maxdfz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz2']=dataschizo['latency_maxdcz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz2']=dataschizo['latency_maxdpz2_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz3']=dataschizo['latency_maxdfz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz3']=dataschizo['latency_maxdcz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz3']=dataschizo['latency_maxdpz3_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxfz4']=dataschizo['latency_maxdfz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxcz4']=dataschizo['latency_maxdcz4_%s' %trial].tolist()
    locals()['featuredictn{0}'.format(trial)]['latency_maxpz4']=dataschizo['latency_maxdpz4_%s' %trial].tolist()
    
    locals()['distractor_df_s{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{0}'.format(trial)].items()]))
    locals()['distractor_df_s{0}'.format(trial)] = locals()['distractor_df_s{0}'.format(trial)].fillna(0)
# Out:
# <ipython-input-34-543cc51ee284>:31: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['distractor_df_s{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{0}'.format(trial)].items()]))

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for trial in range(1,37):
    locals()['featuredicttarget{0}'.format(trial)] = {}
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz1' ]=dataschizo['max_amptfz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz1' ]=dataschizo['max_amptcz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz1' ]=dataschizo['max_amptpz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz2' ]=dataschizo['max_amptfz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz2' ]=dataschizo['max_amptcz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz2' ]=dataschizo['max_amptpz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz3' ]=dataschizo['max_amptfz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz3' ]=dataschizo['max_amptcz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz3' ]=dataschizo['max_amptpz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampfz4' ]=dataschizo['max_amptfz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_ampcz4' ]=dataschizo['max_amptcz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['max_amppz4' ]=dataschizo['max_amptpz4_%s' %trial].tolist()
    
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz1' ]=dataschizo['latency_maxtfz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz1' ]=dataschizo['latency_maxtcz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz1' ]=dataschizo['latency_maxtpz1_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz2' ]=dataschizo['latency_maxtfz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz2' ]=dataschizo['latency_maxtcz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz2' ]=dataschizo['latency_maxtpz2_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz3' ]=dataschizo['latency_maxtfz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz3' ]=dataschizo['latency_maxtcz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz3' ]=dataschizo['latency_maxtpz3_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxfz4' ]=dataschizo['latency_maxtfz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxcz4' ]=dataschizo['latency_maxtcz4_%s' %trial].tolist()
    locals()['featuredicttarget{0}'.format(trial)]['latency_maxpz4' ]=dataschizo['latency_maxtpz4_%s' %trial].tolist()
    
    locals()['target_df_s{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{0}'.format(trial)].items()]))
    locals()['target_df_s{0}'.format(trial)] = locals()['target_df_s{0}'.format(trial)].fillna(0)
# Out:
# <ipython-input-35-4d1d27daa65f>:30: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_s{0}'.format(trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{0}'.format(trial)].items()]))

# %%
dfs = []
for trial in range(1,38):
    #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
    dfs.append(locals()['distractor_df_s{0}'.format(trial)] )
df_distractor_schizo=pd.concat(dfs,ignore_index=True)
df_distractor_schizo=df_distractor_schizo.fillna(0)
df_distractor_schizo
# Out:
#     max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0    31.722496   -2.624448   10.051005   14.644775    7.307546    4.975815
# 1   -34.114697   16.741121   23.531008   41.034718   17.582664   13.397035
# 2   -10.038059    0.000000    0.000000  -54.777153  -68.355682 -102.833397
# 3     6.276167   12.084142   11.918491   18.031242   20.425102   37.553680
# 4    54.214844   -0.628674   13.984084  -25.449556    0.689336   13.984084
# 5    12.549305   13.854393    0.376057   23.624866   26.335491   18.707384
# 6     3.420385    7.156521    4.445970   22.268751   29.066444   34.148109
# 7    25.109919   51.554031   27.011282   13.270634   22.634367   17.079124
# 8    16.921568   19.359098   12.346537   21.997931   19.359098   18.603394
# 9     9.677401    1.046518   19.268820   23.966938   27.206032   39.499714
# 10    7.542312   13.331094   16.159348   15.988702   10.391350   16.159348
# ...

# %%
df_distractor_schizo['label']=0

# %%
dfst = []
for trial in range(1,37):
    #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
    dfst.append(locals()['target_df_s{0}'.format(trial)] )
df_target_schizo=pd.concat(dfst,ignore_index=True)
df_target_schizo=df_target_schizo.fillna(0)
df_target_schizo
# Out:
#     max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     7.127911   28.000109   19.625172   35.254852   28.000109   23.358723
# 1  -102.002876   63.685238    0.000000  148.943420   73.137589   41.188572
# 2    54.915596    4.488643   -9.025017    8.912874   22.315815   13.054923
# 3    22.887676   -5.160201    0.000000    5.122830    8.462801   13.399333
# 4    22.080719   10.359508   13.561571   -9.396413    3.683630   15.605237
# 5    20.355761   24.668526   20.105963   20.232939   24.668526   20.105963
# 6    24.387558   -4.860361   12.876141   12.964174    3.125065    1.524643
# 7    75.736023   -3.535663   -3.939812  -53.919231  -12.925304    0.399743
# 8    17.640196   17.011703   25.299486   33.532787   23.918571   25.299486
# 9     2.603782   33.132008   51.582497   30.639004   33.132008   26.684753
# 10   14.945863   10.399394   -2.110115   30.658400   32.854839   14.331708
# ...

# %%
df_target_schizo['label']=1

# %%
df_schizo=pd.concat([df_distractor_schizo, df_target_schizo] , ignore_index=True)
df_schizo=df_schizo.fillna(0)
df_schizo
# Out:
#     max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0    31.722496   -2.624448   10.051005   14.644775    7.307546    4.975815
# 1   -34.114697   16.741121   23.531008   41.034718   17.582664   13.397035
# 2   -10.038059    0.000000    0.000000  -54.777153  -68.355682 -102.833397
# 3     6.276167   12.084142   11.918491   18.031242   20.425102   37.553680
# 4    54.214844   -0.628674   13.984084  -25.449556    0.689336   13.984084
# ..         ...         ...         ...         ...         ...         ...
# 68   11.267510   34.902119   30.811974  123.767685   80.045929   44.331310
# 69    5.060612    8.697728   -8.625393    9.697508   39.475128   19.124237
# 70   25.217739    1.810582    6.943721   11.862655   19.672951    9.464354
# 71    8.479402   16.990511    8.641911   13.895798   16.990511    8.641911
# 72  116.638275  -32.340759  -17.793564  -80.300285  -32.340759  -16.268858
#
# ...

# %%
X_schizo = df_schizo.loc[:, ~df_schizo.columns.isin(['label'])]
y_schizo = df_schizo['label']

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X_schizo, y_schizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
schizoacc=mean(scores['test_accuracy'])
print(mean(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(mean(scores['test_specificity']))


print(std(scores['test_accuracy']))
print(std(scores['test_sensitivity']))
print(std(scores['test_specificity']))
# Out:
# 0.6267857142857143
# 0.5833333333333333
# 0.675
# 0.15840604309746495
# 0.25276251480171835
# 0.31721443851123804

# %%
#normsubgroup=mean(scores1['test_accuracy'])
resultsubschizo=pd.DataFrame([['for single schizo subject',schizoacc ]],columns=['subjecttype','Accuracy'])
result=result.append(resultsubschizo,ignore_index=True)
result
# Out:
#                       subjecttype  Accuracy
# 0       for single normal subject  0.658929
# 1  for group of 10 normal subject  0.545259
# 2       for single schizo subject  0.626786

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space1 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                
                ]




search_space2 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
               
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space3 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space4 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
               
                ]

search_space5 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}

clf1=GridSearchCV(pipe, search_space1, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf2=GridSearchCV(pipe, search_space2, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf3=GridSearchCV(pipe, search_space3, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf4=GridSearchCV(pipe, search_space4, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf5=GridSearchCV(pipe, search_space5, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores1 = cross_validate(clf1, X_schizo, y_schizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores2 = cross_validate(clf2, X_schizo, y_schizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores3 = cross_validate(clf3, X_schizo, y_schizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores4 = cross_validate(clf4, X_schizo, y_schizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores5 = cross_validate(clf5, X_schizo, y_schizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
print('Logistic Regression accuracy', mean(scores1['test_accuracy']), 'standard deviation', std(scores1['test_accuracy']))
print('Logistic Regression sensitivity ',mean(scores1['test_sensitivity']), 'standard deviation', std(scores1['test_sensitivity'])  )
print('Logistic Regression specificity',mean(scores1['test_specificity']) , 'standard deviation', std(scores1['test_specificity']))

print('\n')

print('Random Forest Classifier accuracy',mean(scores2['test_accuracy']), 'standard deviation', std(scores2['test_accuracy']))
print('Random Forest Classifier sensitivity ',mean(scores2['test_sensitivity']),'standard deviation', std(scores2['test_sensitivity']))
print('Random Forest Classifier specificity',mean(scores2['test_specificity']),'standard deviation', std(scores2['test_specificity']))

print('\n')
print('Decision Tree Classifier accuracy',mean(scores3['test_accuracy']),'standard deviation', std(scores3['test_accuracy']))
print('Decision Tree Classifier sensitivity',mean(scores3['test_sensitivity']),'standard deviation', std(scores3['test_sensitivity']))
print('Decision Tree Classifier specificity',mean(scores3['test_specificity']),'standard deviation', std(scores3['test_specificity']))
print('\n')

print('KNeighborsClassifier accuracy',mean(scores4['test_accuracy']),'standard deviation', std(scores4['test_accuracy']))
print('KNeighborsClassifier sensitivity',mean(scores4['test_sensitivity']),'standard deviation', std(scores4['test_sensitivity']))
print('KNeighborsClassifier specificity',mean(scores4['test_specificity']),'standard deviation', std(scores4['test_specificity']))

print('\n')
print('SVM accuracy',mean(scores5['test_accuracy']),'standard deviation', std(scores5['test_accuracy']))
print('SVM sensitivity',mean(scores5['test_sensitivity']),'standard deviation', std(scores5['test_sensitivity']))
print('SVM specificity',mean(scores5['test_specificity']),'standard deviation', std(scores5['test_specificity']))
# Out:
# Logistic Regression accuracy 0.5392857142857143 standard deviation 0.16652204609821097
# Logistic Regression sensitivity  0.5166666666666666 standard deviation 0.3741657386773941
# Logistic Regression specificity 0.575 standard deviation 0.23702437755546485
#
#
# Random Forest Classifier accuracy 0.5499999999999999 standard deviation 0.16362444555650438
# Random Forest Classifier sensitivity  0.5333333333333333 standard deviation 0.28674417556808757
# Random Forest Classifier specificity 0.5499999999999999 standard deviation 0.1755942292142123
#
#
# Decision Tree Classifier accuracy 0.4821428571428571 standard deviation 0.12058530725810093
# Decision Tree Classifier sensitivity 0.5 standard deviation 0.26614532371118854
# Decision Tree Classifier specificity 0.4499999999999999 standard deviation 0.1755942292142123
#
#
# KNeighborsClassifier accuracy 0.6124999999999999 standard deviation 0.19150484887557587
# ...

# %% [markdown]
# ### for group of 10 schizo subject

# %%
datagroupschizo = loadmat('ERPfeaturegroupschizo.mat')

# %%
featuredictn={}
for sub in range(1,11):
    if sub==1: 
        trials=37 
    elif sub==2:
         trials=42
    elif sub==3:
         trials=25
    elif sub==4:
         trials=36
    elif sub==5:
         trials=39
    elif sub==6:
         trials=39
    elif sub==7:
         trials=35
    elif sub==8:
         trials=39
    elif sub==9:
         trials=39
    elif sub==10:
         trials=26

     
    for trial in range(1,trials+1):
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)] = {}
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz1']=datagroupschizo['max_ampdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz1']=datagroupschizo['max_ampdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz1']=datagroupschizo['max_ampdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz2']=datagroupschizo['max_ampdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz2']=datagroupschizo['max_ampdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz2']=datagroupschizo['max_ampdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz3']=datagroupschizo['max_ampdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz3']=datagroupschizo['max_ampdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz3']=datagroupschizo['max_ampdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz4']=datagroupschizo['max_ampdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz4']=datagroupschizo['max_ampdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz4']=datagroupschizo['max_ampdpz4%s_%s' %(sub ,trial)].tolist()


        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz1']=datagroupschizo['latency_maxdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz1']=datagroupschizo['latency_maxdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz1']=datagroupschizo['latency_maxdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz2']=datagroupschizo['latency_maxdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz2']=datagroupschizo['latency_maxdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz2']=datagroupschizo['latency_maxdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz3']=datagroupschizo['latency_maxdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz3']=datagroupschizo['latency_maxdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz3']=datagroupschizo['latency_maxdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz4']=datagroupschizo['latency_maxdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz4']=datagroupschizo['latency_maxdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz4']=datagroupschizo['latency_maxdpz4%s_%s' %(sub ,trial)].tolist()

        locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
        locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)] = locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)].fillna(0)
# Out:
# <ipython-input-46-8a433a69ab13>:54: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))

# %%
dfsgroupschizo = []
for sub in range(1,11):
    if sub==1: 
        trials=37 
    elif sub==2:
         trials=42
    elif sub==3:
         trials=25
    elif sub==4:
         trials=36
    elif sub==5:
         trials=39
    elif sub==6:
         trials=39
    elif sub==7:
         trials=35
    elif sub==8:
         trials=39
    elif sub==9:
         trials=39
    elif sub==10:
         trials=26

    
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfsgroupschizo.append(locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)] )
        #print(locals()['distractor_df_{0}_{0}'.format(sub,trial)])
        #locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]
    
df_distractorgroupschizo=pd.concat(dfsgroupschizo,ignore_index=True)
df_distractorgroupschizo=df_distractorgroupschizo.fillna(0)
df_distractorgroupschizo
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     31.722496   -2.624448   10.051005   14.644775    7.307546    4.975815
# 1    -34.114697   16.741121   23.531008   41.034718   17.582664   13.397035
# 2    -10.038059    0.000000    0.000000  -54.777153  -68.355682 -102.833397
# 3      6.276167   12.084142   11.918491   18.031242   20.425102   37.553680
# 4     54.214844   -0.628674   13.984084  -25.449556    0.689336   13.984084
# ..          ...         ...         ...         ...         ...         ...
# 352   23.430929    2.397959   -1.831685    2.065825    7.007904    2.440182
# 353    9.687714    9.505692    1.946380   18.738884   14.442062    5.814905
# 354  -30.657404    0.000000    2.458781   21.671110    2.467098   -4.368548
# 355    0.000000   46.091000   38.486431   73.594360   31.316935   19.515265
# 356   58.569099   -3.785799   -0.924383  -46.847687   -3.785799    4.424764
#
# ...

# %%
df_distractorgroupschizo['label']=0

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for sub in range(1,11):
    if sub==1: 
        trials=36 
    elif sub==2:
         trials=41
    elif sub==3:
         trials=31
    elif sub==4:
         trials=36
    elif sub==5:
         trials=40
    elif sub==6:
         trials=39
    elif sub==7:
         trials=37
    elif sub==8:
         trials=40
    elif sub==9:
         trials=39
    elif sub==10:
         trials=36
     
    for trial in range(1,trials+1):
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)] = {}
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz1' ]=datagroupschizo['max_amptfz1%s_%s' %(sub,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz1' ]=datagroupschizo['max_amptcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz1' ]=datagroupschizo['max_amptpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz2' ]=datagroupschizo['max_amptfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz2' ]=datagroupschizo['max_amptcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz2' ]=datagroupschizo['max_amptpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz3' ]=datagroupschizo['max_amptfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz3' ]=datagroupschizo['max_amptcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz3' ]=datagroupschizo['max_amptpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz4' ]=datagroupschizo['max_amptfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz4' ]=datagroupschizo['max_amptcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz4' ]=datagroupschizo['max_amptpz4%s_%s' %(sub ,trial)].tolist()

        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz1' ]=datagroupschizo['latency_maxtfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz1' ]=datagroupschizo['latency_maxtcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz1' ]=datagroupschizo['latency_maxtpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz2' ]=datagroupschizo['latency_maxtfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz2' ]=datagroupschizo['latency_maxtcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz2' ]=datagroupschizo['latency_maxtpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz3' ]=datagroupschizo['latency_maxtfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz3' ]=datagroupschizo['latency_maxtcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz3' ]=datagroupschizo['latency_maxtpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz4' ]=datagroupschizo['latency_maxtfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz4' ]=datagroupschizo['latency_maxtcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz4' ]=datagroupschizo['latency_maxtpz4%s_%s' %(sub ,trial)].tolist()

        locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
        locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)] = locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)].fillna(0)


target_df_schizo3_3.shape
# Out:
# <ipython-input-49-e16b03158aa7>:52: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
# (1, 24)

# %%
dfstgroupschizo = []
for sub in range(1,11):
    if sub==1: 
        trials=36 
    elif sub==2:
         trials=41
    elif sub==3:
         trials=31
    elif sub==4:
         trials=36
    elif sub==5:
         trials=40
    elif sub==6:
         trials=39
    elif sub==7:
         trials=37
    elif sub==8:
         trials=40
    elif sub==9:
         trials=39
    elif sub==10:
         trials=36
     
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfstgroupschizo.append(locals()['target_df_schizo{s}_{t}'.format(s=sub,t=trial)] )
df_targetgroupschizo=pd.concat(dfstgroupschizo,ignore_index=True)
df_targetgroupschizo=df_targetgroupschizo.fillna(0)
df_targetgroupschizo
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      7.127911   28.000109   18.399244   35.254852   28.000109   23.358723
# 1   -102.002876   63.685238    0.000000  148.943420   73.137589   41.188572
# 2     54.915596    4.488643   -9.025017    8.912874   22.315815   13.054923
# 3     22.887676   -5.160201    0.000000    5.122830    8.462801   13.399333
# 4     22.080719   10.359508   13.561571   -9.396413    3.683630   15.605237
# ..          ...         ...         ...         ...         ...         ...
# 370   14.226989   -0.845491   10.411196   15.300998   22.389988   29.636951
# 371   32.210472    0.000000    0.000000   10.415242    8.655411   -0.868066
# 372   60.629173  -14.722795  -12.644495  -41.368992  -14.722795  -10.133014
# 373  -31.087986   17.475740   26.355490   64.823250   42.785954   36.088612
# 374  -34.301685   21.313469    7.077887   73.467506   45.365685   22.003954
#
# ...

# %%
df_targetgroupschizo['label']=1

# %%
df_groupschizo=pd.concat([df_distractorgroupschizo, df_targetgroupschizo] , ignore_index=True)
df_groupschizo=df_groupschizo.fillna(0)
df_groupschizo
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     31.722496   -2.624448   10.051005   14.644775    7.307546    4.975815
# 1    -34.114697   16.741121   23.531008   41.034718   17.582664   13.397035
# 2    -10.038059    0.000000    0.000000  -54.777153  -68.355682 -102.833397
# 3      6.276167   12.084142   11.918491   18.031242   20.425102   37.553680
# 4     54.214844   -0.628674   13.984084  -25.449556    0.689336   13.984084
# ..          ...         ...         ...         ...         ...         ...
# 727   14.226989   -0.845491   10.411196   15.300998   22.389988   29.636951
# 728   32.210472    0.000000    0.000000   10.415242    8.655411   -0.868066
# 729   60.629173  -14.722795  -12.644495  -41.368992  -14.722795  -10.133014
# 730  -31.087986   17.475740   26.355490   64.823250   42.785954   36.088612
# 731  -34.301685   21.313469    7.077887   73.467506   45.365685   22.003954
#
# ...

# %%
X_groupschizo = df_groupschizo.loc[:, ~df_groupschizo.columns.isin(['label'])]
y_groupschizo = df_groupschizo['label']

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                 ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                },
                #{'classifier': [GaussianNB()],
                 
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                 # 'priors' : 'None',
                  #"priors" : "None",
                 # "var_smoothing" : 1e-9
               # }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X_groupschizo, y_groupschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)

schizogroupacc=mean(scores['test_accuracy'])



print(mean(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(mean(scores['test_specificity']))

print(std(scores['test_accuracy']))
print(std(scores['test_sensitivity']))
print(std(scores['test_specificity']))
# Out:
# 0.5123102554609404
# 0.520199146514936
# 0.5042063492063492
# 0.06501970729613424
# 0.06004985022983176
# 0.10279849028285565

# %%
resultsubschizogroup=pd.DataFrame([['for group of 10 schizo subject',schizogroupacc ]],columns=['subjecttype','Accuracy'])
result=result.append(resultsubschizogroup,ignore_index=True)
result
# Out:
#                       subjecttype  Accuracy
# 0       for single normal subject  0.658929
# 1  for group of 10 normal subject  0.545259
# 2       for single schizo subject  0.626786
# 3  for group of 10 schizo subject  0.512310

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                 ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space1 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                
                ]




search_space2 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
               
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space3 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space4 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
               
                ]

search_space5 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}

clf1=GridSearchCV(pipe, search_space1, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf2=GridSearchCV(pipe, search_space2, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf3=GridSearchCV(pipe, search_space3, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf4=GridSearchCV(pipe, search_space4, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf5=GridSearchCV(pipe, search_space5, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)


#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores1 = cross_validate(clf1, X_groupschizo, y_groupschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores2 = cross_validate(clf2, X_groupschizo, y_groupschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores3 = cross_validate(clf3, X_groupschizo, y_groupschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores4 = cross_validate(clf4, X_groupschizo, y_groupschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores5 = cross_validate(clf5, X_groupschizo, y_groupschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)


print('Logistic Regression accuracy', mean(scores1['test_accuracy']), 'standard deviation', std(scores1['test_accuracy']))
print('Logistic Regression sensitivity ',mean(scores1['test_sensitivity']), 'standard deviation', std(scores1['test_sensitivity'])  )
print('Logistic Regression specificity',mean(scores1['test_specificity']) , 'standard deviation', std(scores1['test_specificity']))

print('\n')

print('Random Forest Classifier accuracy',mean(scores2['test_accuracy']), 'standard deviation', std(scores2['test_accuracy']))
print('Random Forest Classifier sensitivity ',mean(scores2['test_sensitivity']),'standard deviation', std(scores2['test_sensitivity']))
print('Random Forest Classifier specificity',mean(scores2['test_specificity']),'standard deviation', std(scores2['test_specificity']))

print('\n')
print('Decision Tree Classifier accuracy',mean(scores3['test_accuracy']),'standard deviation', std(scores3['test_accuracy']))
print('Decision Tree Classifier sensitivity',mean(scores3['test_sensitivity']),'standard deviation', std(scores3['test_sensitivity']))
print('Decision Tree Classifier specificity',mean(scores3['test_specificity']),'standard deviation', std(scores3['test_specificity']))
print('\n')

print('KNeighborsClassifier accuracy',mean(scores4['test_accuracy']),'standard deviation', std(scores4['test_accuracy']))
print('KNeighborsClassifier sensitivity',mean(scores4['test_sensitivity']),'standard deviation', std(scores4['test_sensitivity']))
print('KNeighborsClassifier specificity',mean(scores4['test_specificity']),'standard deviation', std(scores4['test_specificity']))

print('\n')
print('SVM accuracy',mean(scores5['test_accuracy']),'standard deviation', std(scores5['test_accuracy']))
print('SVM sensitivity',mean(scores5['test_sensitivity']),'standard deviation', std(scores5['test_sensitivity']))
print('SVM specificity',mean(scores5['test_specificity']),'standard deviation', std(scores5['test_specificity']))
# Out:
# Logistic Regression accuracy 0.5135690485005553 standard deviation 0.06398815497387216
# Logistic Regression sensitivity  0.5147937411095306 standard deviation 0.04710068333002332
# Logistic Regression specificity 0.5126984126984127 standard deviation 0.1034416568256862
#
#
# Random Forest Classifier accuracy 0.5054054054054054 standard deviation 0.04732855392771311
# Random Forest Classifier sensitivity  0.5283783783783783 standard deviation 0.051218437982879776
# Random Forest Classifier specificity 0.4819047619047619 standard deviation 0.06619142780329224
#
#
# Decision Tree Classifier accuracy 0.49309514994446496 standard deviation 0.04894856334181636
# Decision Tree Classifier sensitivity 0.4853485064011379 standard deviation 0.05764640699671933
# Decision Tree Classifier specificity 0.5011904761904761 standard deviation 0.10005620113837714
#
#
# KNeighborsClassifier accuracy 0.5041466123657904 standard deviation 0.01676408619745729
# ...

# %% [markdown]
# ### For 30 group normal subject

# %%
data30group = loadmat('ERPfeature30group.mat')

# %%
featuredictn={}
for sub in range(1,31):
    if sub==1: 
        trials=39 
    elif sub==2:
         trials=33
    elif sub==3:
         trials=35
    elif sub==4:
         trials=32
    elif sub==5:
         trials=37
    elif sub==6:
         trials=36
    elif sub==7:
         trials=23
    elif sub==8:
         trials=31
    elif sub==9:
         trials=33
    elif sub==10:
         trials=36
            
    
    elif sub==11:
         trials=38
    elif sub==12:
         trials=33
    elif sub==13:
         trials=34
    elif sub==14:
         trials=30
    elif sub==15:
         trials=36
    elif sub==16:
         trials=31
    elif sub==17:
         trials=32
    elif sub==18:
         trials=27
    elif sub==19:
         trials=25

    elif sub==20:
         trials=35
    elif sub==21:
         trials=39
    elif sub==22:
         trials=38
    elif sub==23:
         trials=38
    elif sub==24:
         trials=22
    elif sub==25:
         trials=26
    elif sub==26:
         trials=33
    elif sub==27:
         trials=27
    elif sub==28:
         trials=31
    elif sub==29:
         trials=26
    elif sub==30:
         trials=32

     
    for trial in range(1,trials+1):
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)] = {}
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz1']=data30group['max_ampdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz1']=data30group['max_ampdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz1']=data30group['max_ampdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz2']=data30group['max_ampdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz2']=data30group['max_ampdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz2']=data30group['max_ampdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz3']=data30group['max_ampdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz3']=data30group['max_ampdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz3']=data30group['max_ampdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz4']=data30group['max_ampdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz4']=data30group['max_ampdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz4']=data30group['max_ampdpz4%s_%s' %(sub ,trial)].tolist()


        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz1']=data30group['latency_maxdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz1']=data30group['latency_maxdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz1']=data30group['latency_maxdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz2']=data30group['latency_maxdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz2']=data30group['latency_maxdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz2']=data30group['latency_maxdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz3']=data30group['latency_maxdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz3']=data30group['latency_maxdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz3']=data30group['latency_maxdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz4']=data30group['latency_maxdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz4']=data30group['latency_maxdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz4']=data30group['latency_maxdpz4%s_%s' %(sub ,trial)].tolist()

        locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
        locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)] = locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)].fillna(0)

        
        
distractor_df_3_20.shape
# Out:
# <ipython-input-58-52302a17f8c5>:97: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
# (1, 24)

# %%
dfsgroup = []
for sub in range(1,31):
    if sub==1: 
        trials=39 
    elif sub==2:
         trials=33
    elif sub==3:
         trials=35
    elif sub==4:
         trials=32
    elif sub==5:
         trials=37
    elif sub==6:
         trials=36
    elif sub==7:
         trials=23
    elif sub==8:
         trials=31
    elif sub==9:
         trials=33
    elif sub==10:
         trials=36
            
    
    elif sub==11:
         trials=38
    elif sub==12:
         trials=33
    elif sub==13:
         trials=34
    elif sub==14:
         trials=30
    elif sub==15:
         trials=36
    elif sub==16:
         trials=31
    elif sub==17:
         trials=32
    elif sub==18:
         trials=27
    elif sub==19:
         trials=25

    elif sub==20:
         trials=35
    elif sub==21:
         trials=39
    elif sub==22:
         trials=38
    elif sub==23:
         trials=38
    elif sub==24:
         trials=22
    elif sub==25:
         trials=26
    elif sub==26:
         trials=33
    elif sub==27:
         trials=27
    elif sub==28:
         trials=31
    elif sub==29:
         trials=26
    elif sub==30:
         trials=32

    
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfsgroup.append(locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)] )
        #print(locals()['distractor_df_{0}_{0}'.format(sub,trial)])
        #locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]
    
df_distractor30group=pd.concat(dfsgroup,ignore_index=True)
df_distractor30group=df_distractor30group.fillna(0)
df_distractor30group
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1      4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2      0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3      6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4     82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ..          ...         ...         ...         ...         ...         ...
# 963   37.052868   -2.874838    5.121003   -1.498430   -2.874838    5.121003
# 964    8.025044    3.279835    6.538930   35.927795   27.472498   19.826948
# 965   12.266559    7.957170    3.690588   48.277153   42.065807   30.982656
# 966   30.656601    4.075534    5.075557   10.550747    4.075534   11.236690
# 967  -11.874352   16.422831   21.318220   37.765411   36.182114   35.866318
#
# ...

# %%
df_distractor30group['label']=0

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for sub in range(1,31):
    if sub==1: 
        trials=40 
    elif sub==2:
         trials=36
    elif sub==3:
         trials=35
    elif sub==4:
         trials=36
    elif sub==5:
         trials=35
    elif sub==6:
         trials=31
    elif sub==7:
         trials=29
    elif sub==8:
         trials=29
    elif sub==9:
         trials=37
    elif sub==10:
         trials=34
            
    elif sub==11:
         trials=36
    elif sub==12:
         trials=28
    elif sub==13:
         trials=30
    elif sub==14:
         trials=31
    elif sub==15:
         trials=35
    elif sub==16:
         trials=26
    elif sub==17:
         trials=37
    elif sub==18:
         trials=31
    elif sub==19:
         trials=23

    elif sub==20:
         trials=30
    elif sub==21:
         trials=37
    elif sub==22:
         trials=37
    elif sub==23:
         trials=33
    elif sub==24:
         trials=22
    elif sub==25:
         trials=23
    elif sub==26:
         trials=31
    elif sub==27:
         trials=21
    elif sub==28:
         trials=27
    elif sub==29:
         trials=22
    elif sub==30:
         trials=30
     
    for trial in range(1,trials+1):
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)] = {}
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz1' ]=data30group['max_amptfz1%s_%s' %(sub,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz1' ]=data30group['max_amptcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz1' ]=data30group['max_amptpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz2' ]=data30group['max_amptfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz2' ]=data30group['max_amptcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz2' ]=data30group['max_amptpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz3' ]=data30group['max_amptfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz3' ]=data30group['max_amptcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz3' ]=data30group['max_amptpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz4' ]=data30group['max_amptfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz4' ]=data30group['max_amptcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz4' ]=data30group['max_amptpz4%s_%s' %(sub ,trial)].tolist()

        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz1' ]=data30group['latency_maxtfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz1' ]=data30group['latency_maxtcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz1' ]=data30group['latency_maxtpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz2' ]=data30group['latency_maxtfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz2' ]=data30group['latency_maxtcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz2' ]=data30group['latency_maxtpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz3' ]=data30group['latency_maxtfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz3' ]=data30group['latency_maxtcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz3' ]=data30group['latency_maxtpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz4' ]=data30group['latency_maxtfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz4' ]=data30group['latency_maxtcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz4' ]=data30group['latency_maxtpz4%s_%s' %(sub ,trial)].tolist()

        locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
        locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)] = locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)].fillna(0)


target_df_3_3.shape
# Out:
# <ipython-input-61-02fab5563764>:94: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
# (1, 24)

# %%
dfstgroup = []
for sub in range(1,31):
    if sub==1: 
        trials=40 
    elif sub==2:
         trials=36
    elif sub==3:
         trials=35
    elif sub==4:
         trials=36
    elif sub==5:
         trials=35
    elif sub==6:
         trials=31
    elif sub==7:
         trials=29
    elif sub==8:
         trials=29
    elif sub==9:
         trials=37
    elif sub==10:
         trials=34
            
    elif sub==11:
         trials=36
    elif sub==12:
         trials=28
    elif sub==13:
         trials=30
    elif sub==14:
         trials=31
    elif sub==15:
         trials=35
    elif sub==16:
         trials=26
    elif sub==17:
         trials=37
    elif sub==18:
         trials=31
    elif sub==19:
         trials=23

    elif sub==20:
         trials=30
    elif sub==21:
         trials=37
    elif sub==22:
         trials=37
    elif sub==23:
         trials=33
    elif sub==24:
         trials=22
    elif sub==25:
         trials=23
    elif sub==26:
         trials=31
    elif sub==27:
         trials=21
    elif sub==28:
         trials=27
    elif sub==29:
         trials=22
    elif sub==30:
         trials=30
     
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfstgroup.append(locals()['target_df_{s}_{t}'.format(s=sub,t=trial)] )
df_target30group=pd.concat(dfstgroup,ignore_index=True)
df_target30group=df_target30group.fillna(0)
df_target30group
# Out:
#      max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0     34.009487    0.000000    0.000000   23.372818   21.690861   12.316854
# 1      0.000000   50.831646   31.864912   22.725946   25.759485   20.879736
# 2     32.939423   -2.582398   20.934744    0.855119   -3.710462   20.934744
# 3      7.605074    2.194859   20.437674   32.597767   35.201843   36.077045
# 4     23.039204   -0.402013   -1.437285   -9.358294    1.014682   27.943575
# ..          ...         ...         ...         ...         ...         ...
# 927    7.020203   10.866656   13.205909   20.553514   14.034262   13.205909
# 928   20.753389   -2.331936   -8.551270   10.238124    9.121911   -1.499470
# 929   40.509399   -3.333708    3.042768   -1.124820    1.689626    3.042768
# 930   33.654110   18.220835   27.916809   11.082693   18.220835   25.984282
# 931   32.805424    3.837557   20.845211   -0.877912    3.992272   20.845211
#
# ...

# %%
df_target30group['label']=1

# %%
df_group30=pd.concat([df_distractor30group, df_target30group] , ignore_index=True)
df_group30=df_group30.fillna(0)
df_group30
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0       7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1       4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2       0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3       6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4      82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ...          ...         ...         ...         ...         ...         ...
# 1895    7.020203   10.866656   13.205909   20.553514   14.034262   13.205909
# 1896   20.753389   -2.331936   -8.551270   10.238124    9.121911   -1.499470
# 1897   40.509399   -3.333708    3.042768   -1.124820    1.689626    3.042768
# 1898   33.654110   18.220835   27.916809   11.082693   18.220835   25.984282
# 1899   32.805424    3.837557   20.845211   -0.877912    3.992272   20.845211
#
# ...

# %%
X_group30 = df_group30.loc[:, ~df_group30.columns.isin(['label'])]
y_group30 = df_group30['label']

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA()),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X_group30, y_group30, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
print(mean(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(mean(scores['test_specificity']))
# Out:
# 0.6042105263157895
# 0.5868451155342027
# 0.6208655498281788

# %% [markdown]
# ### For all group normal subject

# %%
dataallgroup = loadmat('ERPfeatureallgroup.mat')

# %%
featuredictn={}
for sub in range(1,55):
    if sub==1: 
        trials=39 
    elif sub==2:
         trials=33
    elif sub==3:
         trials=35
    elif sub==4:
         trials=32
    elif sub==5:
         trials=37
    elif sub==6:
         trials=36
    elif sub==7:
         trials=23
    elif sub==8:
         trials=31
    elif sub==9:
         trials=33
    elif sub==10:
         trials=36
            
    
    elif sub==11:
         trials=38
    elif sub==12:
         trials=33
    elif sub==13:
         trials=34
    elif sub==14:
         trials=30
    elif sub==15:
         trials=36
    elif sub==16:
         trials=31
    elif sub==17:
         trials=32
    elif sub==18:
         trials=27
    elif sub==19:
         trials=25

    elif sub==20:
         trials=35
    elif sub==21:
         trials=39
    elif sub==22:
         trials=38
    elif sub==23:
         trials=38
    elif sub==24:
         trials=22
    elif sub==25:
         trials=26
    elif sub==26:
         trials=33
    elif sub==27:
         trials=27
    elif sub==28:
         trials=31
    elif sub==29:
         trials=26
    elif sub==30:
         trials=32
            
    elif sub==31:
         trials=34
    elif sub==32:
         trials=18
    elif sub==33:
         trials=35
    elif sub==34:
         trials=33
    elif sub==35:
         trials=36
    elif sub==36:
         trials=24
    elif sub==37:
         trials=31
    elif sub==38:
         trials=36
    elif sub==39:
         trials=31
    elif sub==40:
         trials=23
    elif sub==41:
         trials=16
            
    elif sub==42:
         trials=27
    elif sub==43:
         trials=25
    elif sub==44:
         trials=23
    elif sub==45:
         trials=32
    elif sub==46:
         trials=29
    elif sub==47:
         trials=21
    elif sub==48:
         trials=30
    elif sub==49:
         trials=37
    elif sub==50:
         trials=35
    elif sub==51:
         trials=34
    elif sub==52:
         trials=31
    elif sub==53:
         trials=29
    elif sub==54:
         trials=25

     
    for trial in range(1,trials+1):
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)] = {}
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz1']=dataallgroup['max_ampdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz1']=dataallgroup['max_ampdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz1']=dataallgroup['max_ampdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz2']=dataallgroup['max_ampdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz2']=dataallgroup['max_ampdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz2']=dataallgroup['max_ampdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz3']=dataallgroup['max_ampdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz3']=dataallgroup['max_ampdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz3']=dataallgroup['max_ampdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz4']=dataallgroup['max_ampdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz4']=dataallgroup['max_ampdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz4']=dataallgroup['max_ampdpz4%s_%s' %(sub ,trial)].tolist()


        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz1']=dataallgroup['latency_maxdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz1']=dataallgroup['latency_maxdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz1']=dataallgroup['latency_maxdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz2']=dataallgroup['latency_maxdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz2']=dataallgroup['latency_maxdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz2']=dataallgroup['latency_maxdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz3']=dataallgroup['latency_maxdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz3']=dataallgroup['latency_maxdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz3']=dataallgroup['latency_maxdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz4']=dataallgroup['latency_maxdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz4']=dataallgroup['latency_maxdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz4']=dataallgroup['latency_maxdpz4%s_%s' %(sub ,trial)].tolist()

        locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
        locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)] = locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)].fillna(0)

        
        
distractor_df_3_20.shape
# Out:
# <ipython-input-68-64134bdde016>:147: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
# (1, 24)

# %%
dfsgroup = []
for sub in range(1,55):
    if sub==1: 
        trials=39 
    elif sub==2:
         trials=33
    elif sub==3:
         trials=35
    elif sub==4:
         trials=32
    elif sub==5:
         trials=37
    elif sub==6:
         trials=36
    elif sub==7:
         trials=23
    elif sub==8:
         trials=31
    elif sub==9:
         trials=33
    elif sub==10:
         trials=36
            
    
    elif sub==11:
         trials=38
    elif sub==12:
         trials=33
    elif sub==13:
         trials=34
    elif sub==14:
         trials=30
    elif sub==15:
         trials=36
    elif sub==16:
         trials=31
    elif sub==17:
         trials=32
    elif sub==18:
         trials=27
    elif sub==19:
         trials=25

    elif sub==20:
         trials=35
    elif sub==21:
         trials=39
    elif sub==22:
         trials=38
    elif sub==23:
         trials=38
    elif sub==24:
         trials=22
    elif sub==25:
         trials=26
    elif sub==26:
         trials=33
    elif sub==27:
         trials=27
    elif sub==28:
         trials=31
    elif sub==29:
         trials=26
    elif sub==30:
         trials=32
            
    elif sub==31:
         trials=34
    elif sub==32:
         trials=18
    elif sub==33:
         trials=35
    elif sub==34:
         trials=33
    elif sub==35:
         trials=36
    elif sub==36:
         trials=24
    elif sub==37:
         trials=31
    elif sub==38:
         trials=36
    elif sub==39:
         trials=31
    elif sub==40:
         trials=23
    elif sub==41:
         trials=16
            
    elif sub==42:
         trials=27
    elif sub==43:
         trials=25
    elif sub==44:
         trials=23
    elif sub==45:
         trials=32
    elif sub==46:
         trials=29
    elif sub==47:
         trials=21
    elif sub==48:
         trials=30
    elif sub==49:
         trials=37
    elif sub==50:
         trials=35
    elif sub==51:
         trials=34
    elif sub==52:
         trials=31
    elif sub==53:
         trials=29
    elif sub==54:
         trials=25
    
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfsgroup.append(locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)] )
        #print(locals()['distractor_df_{0}_{0}'.format(sub,trial)])
        #locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]
    
df_distractorallgroup=pd.concat(dfsgroup,ignore_index=True)
df_distractorallgroup=df_distractorallgroup.fillna(0)
df_distractorallgroup
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0       7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1       4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2       0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3       6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4      82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ...          ...         ...         ...         ...         ...         ...
# 1658    0.819288    8.414665    1.719871   24.458248   18.092218    2.914372
# 1659   37.390099   30.095217   23.586880   75.235977   33.904697   23.586880
# 1660    1.569636    5.685665    7.322568   17.019800   22.270758   14.449783
# 1661   42.785900    0.000000    0.000000  -23.222124   -5.252287   -7.071825
# 1662   -2.516644    4.328402    0.000000   20.476404    3.998542    9.565374
#
# ...

# %%
df_distractorallgroup['label']=0

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for sub in range(1,55):
    if sub==1: 
        trials=40 
    elif sub==2:
         trials=36
    elif sub==3:
         trials=35
    elif sub==4:
         trials=36
    elif sub==5:
         trials=35
    elif sub==6:
         trials=31
    elif sub==7:
         trials=29
    elif sub==8:
         trials=29
    elif sub==9:
         trials=37
    elif sub==10:
         trials=34
            
    elif sub==11:
         trials=36
    elif sub==12:
         trials=28
    elif sub==13:
         trials=30
    elif sub==14:
         trials=31
    elif sub==15:
         trials=35
    elif sub==16:
         trials=26
    elif sub==17:
         trials=37
    elif sub==18:
         trials=31
    elif sub==19:
         trials=23

    elif sub==20:
         trials=30
    elif sub==21:
         trials=37
    elif sub==22:
         trials=37
    elif sub==23:
         trials=33
    elif sub==24:
         trials=22
    elif sub==25:
         trials=23
    elif sub==26:
         trials=31
    elif sub==27:
         trials=21
    elif sub==28:
         trials=27
    elif sub==29:
         trials=22
    elif sub==30:
         trials=30
            
    elif sub==31:
         trials=34
    elif sub==32:
         trials=12
    elif sub==33:
         trials=31
    elif sub==34:
         trials=36
    elif sub==35:
         trials=34
    elif sub==36:
         trials=29
    elif sub==37:
         trials=33
    elif sub==38:
         trials=35
    elif sub==39:
         trials=20
    elif sub==40:
         trials=21
    elif sub==41:
         trials=8
    elif sub==42:
         trials=32
    elif sub==43:
         trials=24
    elif sub==44:
         trials=18
    elif sub==45:
         trials=26
    elif sub==46:
         trials=29
    elif sub==47:
         trials=20
    elif sub==48:
         trials=33
    elif sub==49:
         trials=38
    elif sub==50:
         trials=38
    elif sub==51:
         trials=39
    elif sub==52:
         trials=36
    elif sub==53:
         trials=20
    elif sub==54:
         trials=17
     
    for trial in range(1,trials+1):
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)] = {}
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz1' ]=dataallgroup['max_amptfz1%s_%s' %(sub,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz1' ]=dataallgroup['max_amptcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz1' ]=dataallgroup['max_amptpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz2' ]=dataallgroup['max_amptfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz2' ]=dataallgroup['max_amptcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz2' ]=dataallgroup['max_amptpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz3' ]=dataallgroup['max_amptfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz3' ]=dataallgroup['max_amptcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz3' ]=dataallgroup['max_amptpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz4' ]=dataallgroup['max_amptfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz4' ]=dataallgroup['max_amptcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz4' ]=dataallgroup['max_amptpz4%s_%s' %(sub ,trial)].tolist()

        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz1' ]=dataallgroup['latency_maxtfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz1' ]=dataallgroup['latency_maxtcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz1' ]=dataallgroup['latency_maxtpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz2' ]=dataallgroup['latency_maxtfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz2' ]=dataallgroup['latency_maxtcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz2' ]=dataallgroup['latency_maxtpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz3' ]=dataallgroup['latency_maxtfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz3' ]=dataallgroup['latency_maxtcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz3' ]=dataallgroup['latency_maxtpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz4' ]=dataallgroup['latency_maxtfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz4' ]=dataallgroup['latency_maxtcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz4' ]=dataallgroup['latency_maxtpz4%s_%s' %(sub ,trial)].tolist()

        locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
        locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)] = locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)].fillna(0)


target_df_3_3.shape
# Out:
# <ipython-input-71-9981a8cf4388>:143: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
# (1, 24)

# %%
dfstgroup = []
for sub in range(1,55):
    if sub==1: 
        trials=40 
    elif sub==2:
         trials=36
    elif sub==3:
         trials=35
    elif sub==4:
         trials=36
    elif sub==5:
         trials=35
    elif sub==6:
         trials=31
    elif sub==7:
         trials=29
    elif sub==8:
         trials=29
    elif sub==9:
         trials=37
    elif sub==10:
         trials=34
            
    elif sub==11:
         trials=36
    elif sub==12:
         trials=28
    elif sub==13:
         trials=30
    elif sub==14:
         trials=31
    elif sub==15:
         trials=35
    elif sub==16:
         trials=26
    elif sub==17:
         trials=37
    elif sub==18:
         trials=31
    elif sub==19:
         trials=23

    elif sub==20:
         trials=30
    elif sub==21:
         trials=37
    elif sub==22:
         trials=37
    elif sub==23:
         trials=33
    elif sub==24:
         trials=22
    elif sub==25:
         trials=23
    elif sub==26:
         trials=31
    elif sub==27:
         trials=21
    elif sub==28:
         trials=27
    elif sub==29:
         trials=22
    elif sub==30:
         trials=30
            
    elif sub==31:
         trials=34
    elif sub==32:
         trials=12
    elif sub==33:
         trials=31
    elif sub==34:
         trials=36
    elif sub==35:
         trials=34
    elif sub==36:
         trials=29
    elif sub==37:
         trials=33
    elif sub==38:
         trials=35
    elif sub==39:
         trials=20
    elif sub==40:
         trials=21
    elif sub==41:
         trials=8
    elif sub==42:
         trials=32
    elif sub==43:
         trials=24
    elif sub==44:
         trials=18
    elif sub==45:
         trials=26
    elif sub==46:
         trials=29
    elif sub==47:
         trials=20
    elif sub==48:
         trials=33
    elif sub==49:
         trials=38
    elif sub==50:
         trials=38
    elif sub==51:
         trials=39
    elif sub==52:
         trials=36
    elif sub==53:
         trials=20
    elif sub==54:
         trials=17
     
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfstgroup.append(locals()['target_df_{s}_{t}'.format(s=sub,t=trial)] )
df_targetallgroup=pd.concat(dfstgroup,ignore_index=True)
df_targetallgroup=df_targetallgroup.fillna(0)
df_targetallgroup
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      34.009487    0.000000    0.000000   23.372818   21.690861   12.316854
# 1       0.000000   50.831646   31.864912   22.725946   25.759485   20.879736
# 2      32.939423   -2.582398   20.934744    0.855119   -3.710462   20.934744
# 3       7.605074    2.194859   20.437674   32.597767   35.201843   36.077045
# 4      23.039204   -0.402013   -1.437285   -9.358294    1.014682   27.943575
# ...          ...         ...         ...         ...         ...         ...
# 1590   32.095615    0.000000    5.181990    5.273594    2.586826    7.988588
# 1591    7.316875    1.351572    4.839580    6.316287    0.645029    7.458270
# 1592    1.549303    5.455801    0.000000   21.808544   16.505013    9.853597
# 1593   14.412125    9.151902    8.167463   -5.577915    1.011994    6.879813
# 1594   35.467613    0.000000  -10.628722    2.715727    5.177238    5.794801
#
# ...

# %%
df_targetallgroup['label']=1

# %%
df_groupall=pd.concat([df_distractorallgroup, df_targetallgroup] , ignore_index=True)
df_groupall=df_groupall.fillna(0)
df_groupall
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0       7.795794    8.907994    9.712512   22.645699   23.346849   18.431763
# 1       4.585493   15.314556   30.073944   14.307274   21.298868   35.594460
# 2       0.611558   31.922592   21.757448   33.639877   31.469799   13.445862
# 3       6.271417    8.785181    0.000000   62.319523   32.206097   47.631283
# 4      82.908600  -34.943577  -47.244099  -48.023693  -38.094063  -36.040966
# ...          ...         ...         ...         ...         ...         ...
# 3253   32.095615    0.000000    5.181990    5.273594    2.586826    7.988588
# 3254    7.316875    1.351572    4.839580    6.316287    0.645029    7.458270
# 3255    1.549303    5.455801    0.000000   21.808544   16.505013    9.853597
# 3256   14.412125    9.151902    8.167463   -5.577915    1.011994    6.879813
# 3257   35.467613    0.000000  -10.628722    2.715727    5.177238    5.794801
#
# ...

# %%
X_groupall = df_groupall.loc[:, ~df_groupall.columns.isin(['label'])]
y_groupall = df_groupall['label']

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                  ('pca', PCA()),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X_groupall, y_groupall, scoring=scoring, cv=cv_outer, n_jobs=-1)
#print(scores1)
print(mean(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(mean(scores['test_specificity']))


print(std(scores['test_accuracy']))
print(std(scores['test_sensitivity']))
print(std(scores['test_specificity']))
# Out:
# 0.5877904672015102
# 0.5605542452830189
# 0.6139924969338432
# 0.02625042238865696
# 0.04437958275754908
# 0.04038668569316625

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                 ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space1 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                
                ]




search_space2 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
               
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space3 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space4 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
               
                ]

search_space5 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}

clf1=GridSearchCV(pipe, search_space1, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf2=GridSearchCV(pipe, search_space2, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf3=GridSearchCV(pipe, search_space3, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf4=GridSearchCV(pipe, search_space4, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf5=GridSearchCV(pipe, search_space5, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)


#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores1 = cross_validate(clf1, X_groupall, y_groupall, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores2 = cross_validate(clf2, X_groupall, y_groupall, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores3 = cross_validate(clf3, X_groupall, y_groupall, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores4 = cross_validate(clf4, X_groupall, y_groupall, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores5 = cross_validate(clf5, X_groupall, y_groupall, scoring=scoring, cv=cv_outer, n_jobs=-1)


print('Logistic Regression accuracy', mean(scores1['test_accuracy']), 'standard deviation', std(scores1['test_accuracy']))
print('Logistic Regression sensitivity ',mean(scores1['test_sensitivity']), 'standard deviation', std(scores1['test_sensitivity'])  )
print('Logistic Regression specificity',mean(scores1['test_specificity']) , 'standard deviation', std(scores1['test_specificity']))

print('\n')

print('Random Forest Classifier accuracy',mean(scores2['test_accuracy']), 'standard deviation', std(scores2['test_accuracy']))
print('Random Forest Classifier sensitivity ',mean(scores2['test_sensitivity']),'standard deviation', std(scores2['test_sensitivity']))
print('Random Forest Classifier specificity',mean(scores2['test_specificity']),'standard deviation', std(scores2['test_specificity']))

print('\n')
print('Decision Tree Classifier accuracy',mean(scores3['test_accuracy']),'standard deviation', std(scores3['test_accuracy']))
print('Decision Tree Classifier sensitivity',mean(scores3['test_sensitivity']),'standard deviation', std(scores3['test_sensitivity']))
print('Decision Tree Classifier specificity',mean(scores3['test_specificity']),'standard deviation', std(scores3['test_specificity']))
print('\n')

print('KNeighborsClassifier accuracy',mean(scores4['test_accuracy']),'standard deviation', std(scores4['test_accuracy']))
print('KNeighborsClassifier sensitivity',mean(scores4['test_sensitivity']),'standard deviation', std(scores4['test_sensitivity']))
print('KNeighborsClassifier specificity',mean(scores4['test_specificity']),'standard deviation', std(scores4['test_specificity']))

print('\n')
print('SVM accuracy',mean(scores5['test_accuracy']),'standard deviation', std(scores5['test_accuracy']))
print('SVM sensitivity',mean(scores5['test_sensitivity']),'standard deviation', std(scores5['test_sensitivity']))
print('SVM specificity',mean(scores5['test_specificity']),'standard deviation', std(scores5['test_specificity']))
# Out:
# Logistic Regression accuracy 0.5905455403492214 standard deviation 0.023838653787663436
# Logistic Regression sensitivity  0.5643278301886793 standard deviation 0.05346408553631387
# Logistic Regression specificity 0.6157528316860256 standard deviation 0.045333469982222215
#
#
# Random Forest Classifier accuracy 0.5942312411514866 standard deviation 0.028314663451673956
# Random Forest Classifier sensitivity  0.5655738993710692 standard deviation 0.051062109938173915
# Random Forest Classifier specificity 0.6217913570449463 standard deviation 0.05146370035670939
#
#
# Decision Tree Classifier accuracy 0.5877725342142519 standard deviation 0.03154369368341679
# Decision Tree Classifier sensitivity 0.5605227987421384 standard deviation 0.05259175147691768
# Decision Tree Classifier specificity 0.6139239593102951 standard deviation 0.04898940013560214
#
#
# KNeighborsClassifier accuracy 0.5874723926380367 standard deviation 0.025530817661353896
# ...

# %% [markdown]
# ### For 54 group of  schizo subject

# %%
dataallgroupschizo = loadmat('ERPfeatureallgroupschizo.mat')

# %%
featuredictn={}
for sub in range(1,55):
    if sub==1: 
        trials=37 
    elif sub==2:
         trials=42
    elif sub==3:
         trials=25
    elif sub==4:
         trials=36
    elif sub==5:
         trials=39
    elif sub==6:
         trials=39
    elif sub==7:
         trials=35
    elif sub==8:
         trials=39
    elif sub==9:
         trials=39
    elif sub==10:
         trials=26
    elif sub==11: 
        trials=42 
    elif sub==12:
         trials=35
    elif sub==13:
         trials=37
    elif sub==14:
         trials=29
    elif sub==15:
         trials=37
    elif sub==16:
         trials=35
    elif sub==17:
         trials=35
    elif sub==18:
         trials=17
    elif sub==19:
         trials=30
    elif sub==20:
         trials=33 
    elif sub==21:
         trials=40
    elif sub==22:
         trials=34
    elif sub==23:
         trials=40
    elif sub==24:
         trials=36
    elif sub==25:
         trials=34
    elif sub==26:
         trials=33
    elif sub==27:
         trials=32
    elif sub==28:
         trials=37
    elif sub==29:
         trials=29
    elif sub==30: 
        trials=36 
    elif sub==31:
         trials=41
    elif sub==32:
         trials=11
    elif sub==33:
         trials=27
    elif sub==34:
         trials=39
    elif sub==35:
         trials=22
    elif sub==36:
         trials=30
    elif sub==37:
         trials=37
    elif sub==38:
         trials=23
    elif sub==39:
         trials=27
    elif sub==40: 
        trials=33 
    elif sub==41:
         trials=21
    elif sub==42:
         trials=39
    elif sub==43:
         trials=26
    elif sub==44:
         trials=25
    elif sub==45:
         trials=32
    elif sub==46:
         trials=36
    elif sub==47:
         trials=38
    elif sub==48:
         trials=38
    elif sub==49:
         trials=35
    elif sub==50:
         trials=38
    elif sub==51:
         trials=38
    elif sub==52:
         trials=39
    elif sub==53:
         trials=20
    elif sub==54:
         trials=36
     
    for trial in range(1,trials+1):
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)] = {}
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz1']=dataallgroupschizo['max_ampdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz1']=dataallgroupschizo['max_ampdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz1']=dataallgroupschizo['max_ampdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz2']=dataallgroupschizo['max_ampdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz2']=dataallgroupschizo['max_ampdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz2']=dataallgroupschizo['max_ampdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz3']=dataallgroupschizo['max_ampdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz3']=dataallgroupschizo['max_ampdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz3']=dataallgroupschizo['max_ampdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampfz4']=dataallgroupschizo['max_ampdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_ampcz4']=dataallgroupschizo['max_ampdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['max_amppz4']=dataallgroupschizo['max_ampdpz4%s_%s' %(sub ,trial)].tolist()


        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz1']=dataallgroupschizo['latency_maxdfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz1']=dataallgroupschizo['latency_maxdcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz1']=dataallgroupschizo['latency_maxdpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz2']=dataallgroupschizo['latency_maxdfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz2']=dataallgroupschizo['latency_maxdcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz2']=dataallgroupschizo['latency_maxdpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz3']=dataallgroupschizo['latency_maxdfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz3']=dataallgroupschizo['latency_maxdcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz3']=dataallgroupschizo['latency_maxdpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxfz4']=dataallgroupschizo['latency_maxdfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxcz4']=dataallgroupschizo['latency_maxdcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)]['latency_maxpz4']=dataallgroupschizo['latency_maxdpz4%s_%s' %(sub ,trial)].tolist()

        locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))
        locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)] = locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)].fillna(0)
# Out:
# <ipython-input-79-a35aa46a67fc>:141: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredictn{s}_{t}'.format(s=sub,t=trial)].items()]))

# %%
dfsgroupschizo = []
for sub in range(1,55):
    if sub==1: 
        trials=37 
    elif sub==2:
         trials=42
    elif sub==3:
         trials=25
    elif sub==4:
         trials=36
    elif sub==5:
         trials=39
    elif sub==6:
         trials=39
    elif sub==7:
         trials=35
    elif sub==8:
         trials=39
    elif sub==9:
         trials=39
    elif sub==10:
         trials=26
    elif sub==11: 
        trials=42 
    elif sub==12:
         trials=35
    elif sub==13:
         trials=37
    elif sub==14:
         trials=29
    elif sub==15:
         trials=37
    elif sub==16:
         trials=35
    elif sub==17:
         trials=35
    elif sub==18:
         trials=17
    elif sub==19:
         trials=30
    elif sub==20:
         trials=33 
    elif sub==21:
         trials=40
    elif sub==22:
         trials=34
    elif sub==23:
         trials=40
    elif sub==24:
         trials=36
    elif sub==25:
         trials=34
    elif sub==26:
         trials=33
    elif sub==27:
         trials=32
    elif sub==28:
         trials=37
    elif sub==29:
         trials=29
    elif sub==30: 
        trials=36 
    elif sub==31:
         trials=41
    elif sub==32:
         trials=11
    elif sub==33:
         trials=27
    elif sub==34:
         trials=39
    elif sub==35:
         trials=22
    elif sub==36:
         trials=30
    elif sub==37:
         trials=37
    elif sub==38:
         trials=23
    elif sub==39:
         trials=27
    elif sub==40: 
        trials=33 
    elif sub==41:
         trials=21
    elif sub==42:
         trials=39
    elif sub==43:
         trials=26
    elif sub==44:
         trials=25
    elif sub==45:
         trials=32
    elif sub==46:
         trials=36
    elif sub==47:
         trials=38
    elif sub==48:
         trials=38
    elif sub==49:
         trials=35
    elif sub==50:
         trials=38
    elif sub==51:
         trials=38
    elif sub==52:
         trials=39
    elif sub==53:
         trials=20
    elif sub==54:
         trials=36

    
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfsgroupschizo.append(locals()['distractor_df_schizo{s}_{t}'.format(s=sub,t=trial)] )
        #print(locals()['distractor_df_{0}_{0}'.format(sub,trial)])
        #locals()['distractor_df_{s}_{t}'.format(s=sub,t=trial)]
    
df_distractorgroupschizoall=pd.concat(dfsgroupschizo,ignore_index=True)
df_distractorgroupschizoall=df_distractorgroupschizoall.fillna(0)
df_distractorgroupschizoall
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      31.722496   -2.624448   10.051005   14.644775    7.307546    4.975815
# 1     -34.114697   16.741121   23.531008   41.034718   17.582664   13.397035
# 2     -10.038059    0.000000    0.000000  -54.777153  -68.355682 -102.833397
# 3       6.276167   12.084142   11.918491   18.031242   20.425102   37.553680
# 4      54.214844   -0.628674   13.984084  -25.449556    0.689336   13.984084
# ...          ...         ...         ...         ...         ...         ...
# 1784    9.338167    1.915387    1.501756   -1.935462    1.915387    7.626576
# 1785   31.866665    4.865755    7.456482   -1.320153    1.941638   20.723026
# 1786   26.371384   -7.749453   -1.533027    0.813399   -0.837887   21.287794
# 1787  -83.027710   50.220654    0.000000   93.829384   51.822735   51.960445
# 1788   27.973110   21.933100    4.914329   12.743032   19.500414   23.854528
#
# ...

# %%
df_distractorgroupschizoall['label']=0

# %% [markdown]
#  ### target features

# %%
featuredicttarget={}
for sub in range(1,55):
    if sub==1: 
        trials=36 
    elif sub==2:
         trials=41
    elif sub==3:
         trials=31
    elif sub==4:
         trials=36
    elif sub==5:
         trials=40
    elif sub==6:
         trials=39
    elif sub==7:
         trials=37
    elif sub==8:
         trials=40
    elif sub==9:
         trials=39
    elif sub==10:
         trials=36
            
    elif sub==11: 
        trials=43 
    elif sub==12:
         trials=37
    elif sub==13:
         trials=34
    elif sub==14:
         trials=14
    elif sub==15:
         trials=33
    elif sub==16:
         trials=34
    elif sub==17:
         trials=27
    elif sub==18:
         trials=7
    elif sub==19:
         trials=28
    elif sub==20:
         trials=32 
    elif sub==21:
         trials=44
    elif sub==22:
         trials=40
    elif sub==23:
         trials=35
    elif sub==24:
         trials=37
    elif sub==25:
         trials=32
    elif sub==26:
         trials=32
    elif sub==27:
         trials=30
    elif sub==28:
         trials=40
    elif sub==29:
         trials=23
    elif sub==30: 
        trials=38 
    elif sub==31:
         trials=41
    elif sub==32:
         trials=11
    elif sub==33:
         trials=25
    elif sub==34:
         trials=34
    elif sub==35:
         trials=29
    elif sub==36:
         trials=31
    elif sub==37:
         trials=33
    elif sub==38:
         trials=20
    elif sub==39:
         trials=34
    elif sub==40: 
        trials=36 
    elif sub==41:
         trials=28
    elif sub==42:
         trials=35
    elif sub==43:
         trials=13
    elif sub==44:
         trials=25
    elif sub==45:
         trials=34
    elif sub==46:
         trials=34
    elif sub==47:
         trials=37
    elif sub==48:
         trials=37
    elif sub==49:
         trials=38
    elif sub==50:
         trials=39
    elif sub==51:
         trials=38
    elif sub==52:
         trials=42
    elif sub==53:
         trials=19
    elif sub==54:
         trials=34
     
    for trial in range(1,trials+1):
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)] = {}
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz1' ]=dataallgroupschizo['max_amptfz1%s_%s' %(sub,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz1' ]=dataallgroupschizo['max_amptcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz1' ]=dataallgroupschizo['max_amptpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz2' ]=dataallgroupschizo['max_amptfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz2' ]=dataallgroupschizo['max_amptcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz2' ]=dataallgroupschizo['max_amptpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz3' ]=dataallgroupschizo['max_amptfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz3' ]=dataallgroupschizo['max_amptcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz3' ]=dataallgroupschizo['max_amptpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampfz4' ]=dataallgroupschizo['max_amptfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_ampcz4' ]=dataallgroupschizo['max_amptcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['max_amppz4' ]=dataallgroupschizo['max_amptpz4%s_%s' %(sub ,trial)].tolist()

        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz1' ]=dataallgroupschizo['latency_maxtfz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz1' ]=dataallgroupschizo['latency_maxtcz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz1' ]=dataallgroupschizo['latency_maxtpz1%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz2' ]=dataallgroupschizo['latency_maxtfz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz2' ]=dataallgroupschizo['latency_maxtcz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz2' ]=dataallgroupschizo['latency_maxtpz2%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz3' ]=dataallgroupschizo['latency_maxtfz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz3' ]=dataallgroupschizo['latency_maxtcz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz3' ]=dataallgroupschizo['latency_maxtpz3%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxfz4' ]=dataallgroupschizo['latency_maxtfz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxcz4' ]=dataallgroupschizo['latency_maxtcz4%s_%s' %(sub ,trial)].tolist()
        locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)]['latency_maxpz4' ]=dataallgroupschizo['latency_maxtpz4%s_%s' %(sub ,trial)].tolist()

        locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
        locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)] = locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)].fillna(0)


target_df_schizo3_3.shape
# Out:
# <ipython-input-82-e0b07b367d01>:141: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   locals()['target_df_schizo{s}_{t}'.format(s=sub ,t=trial)]  = pd.DataFrame(dict([(k, pd.Series([a for b in v for a in b])) for k, v in locals()['featuredicttarget{s}_{t}'.format(s=sub ,t=trial)].items()]))
# (1, 24)

# %%
dfstgroupschizo = []
for sub in range(1,55):
    if sub==1: 
        trials=36 
    elif sub==2:
         trials=41
    elif sub==3:
         trials=31
    elif sub==4:
         trials=36
    elif sub==5:
         trials=40
    elif sub==6:
         trials=39
    elif sub==7:
         trials=37
    elif sub==8:
         trials=40
    elif sub==9:
         trials=39
    elif sub==10:
         trials=36
            
    elif sub==11: 
        trials=43 
    elif sub==12:
         trials=37
    elif sub==13:
         trials=34
    elif sub==14:
         trials=14
    elif sub==15:
         trials=33
    elif sub==16:
         trials=34
    elif sub==17:
         trials=27
    elif sub==18:
         trials=7
    elif sub==19:
         trials=28
    elif sub==20:
         trials=32 
    elif sub==21:
         trials=44
    elif sub==22:
         trials=40
    elif sub==23:
         trials=35
    elif sub==24:
         trials=37
    elif sub==25:
         trials=32
    elif sub==26:
         trials=32
    elif sub==27:
         trials=30
    elif sub==28:
         trials=40
    elif sub==29:
         trials=23
    elif sub==30: 
        trials=38 
    elif sub==31:
         trials=41
    elif sub==32:
         trials=11
    elif sub==33:
         trials=25
    elif sub==34:
         trials=34
    elif sub==35:
         trials=29
    elif sub==36:
         trials=31
    elif sub==37:
         trials=33
    elif sub==38:
         trials=20
    elif sub==39:
         trials=34
    elif sub==40: 
        trials=36 
    elif sub==41:
         trials=28
    elif sub==42:
         trials=35
    elif sub==43:
         trials=13
    elif sub==44:
         trials=25
    elif sub==45:
         trials=34
    elif sub==46:
         trials=34
    elif sub==47:
         trials=37
    elif sub==48:
         trials=37
    elif sub==49:
         trials=38
    elif sub==50:
         trials=39
    elif sub==51:
         trials=38
    elif sub==52:
         trials=42
    elif sub==53:
         trials=19
    elif sub==54:
         trials=34
     
    for trial in range(1,trials+1):
        #df_distractor=pd.concat([locals()['distractor_df_{0}'.format(trial)] ],ignore_index=True).fillna(0)
        dfstgroupschizo.append(locals()['target_df_schizo{s}_{t}'.format(s=sub,t=trial)] )
df_targetallgroupschizo=pd.concat(dfstgroupschizo,ignore_index=True)
df_targetallgroupschizo=df_targetallgroupschizo.fillna(0)
df_targetallgroupschizo
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0       7.127911   28.000109   18.399244   35.254852   28.000109   23.358723
# 1    -102.002876   63.685238    0.000000  148.943420   73.137589   41.188572
# 2      54.915596    4.488643   -9.025017    8.912874   22.315815   13.054923
# 3      22.887676   -5.160201    0.000000    5.122830    8.462801   13.399333
# 4      22.080719   10.359508   13.561571   -9.396413    3.683630   15.605237
# ...          ...         ...         ...         ...         ...         ...
# 1757   20.368189    0.000000    0.000000   10.018026    7.449411    8.362567
# 1758    0.843237   30.743975   28.787292   17.005766   28.335518   14.868825
# 1759    3.799574   24.692415   17.560503   25.335636   34.670048   24.076185
# 1760   32.698189    0.000000    0.000000   38.590176   44.119320   25.978001
# 1761   13.657692    7.526292    8.568570    3.784069   15.736539   26.654633
#
# ...

# %%
df_targetallgroupschizo['label']=1

# %%
df_groupallschizo=pd.concat([df_distractorgroupschizoall, df_targetallgroupschizo] , ignore_index=True)
df_groupallschizo=df_groupallschizo.fillna(0)
df_groupallschizo
# Out:
#       max_ampfz1  max_ampcz1  max_amppz1  max_ampfz2  max_ampcz2  max_amppz2  \
# 0      31.722496   -2.624448   10.051005   14.644775    7.307546    4.975815
# 1     -34.114697   16.741121   23.531008   41.034718   17.582664   13.397035
# 2     -10.038059    0.000000    0.000000  -54.777153  -68.355682 -102.833397
# 3       6.276167   12.084142   11.918491   18.031242   20.425102   37.553680
# 4      54.214844   -0.628674   13.984084  -25.449556    0.689336   13.984084
# ...          ...         ...         ...         ...         ...         ...
# 3546   20.368189    0.000000    0.000000   10.018026    7.449411    8.362567
# 3547    0.843237   30.743975   28.787292   17.005766   28.335518   14.868825
# 3548    3.799574   24.692415   17.560503   25.335636   34.670048   24.076185
# 3549   32.698189    0.000000    0.000000   38.590176   44.119320   25.978001
# 3550   13.657692    7.526292    8.568570    3.784069   15.736539   26.654633
#
# ...

# %%
X_groupallschizo = df_groupallschizo.loc[:, ~df_groupallschizo.columns.isin(['label'])]
y_groupallschizo = df_groupallschizo['label']

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                 ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                },
                #{'classifier': [GaussianNB()],
                 
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                 # 'priors' : 'None',
                  #"priors" : "None",
                 # "var_smoothing" : 1e-9
               # }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}
clf=GridSearchCV(pipe, search_space, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)

#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores = cross_validate(clf, X_groupallschizo, y_groupallschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
#coefs = pipe.named_steps["classifier"].feature_importances_
schizogroupacc=mean(scores['test_accuracy'])



print(mean(scores['test_accuracy']))
print(mean(scores['test_sensitivity']))
print(mean(scores['test_specificity']))



print(std(scores['test_accuracy']))
print(std(scores['test_sensitivity']))
print(std(scores['test_specificity']))
# Out:
# 0.5190109194492799
# 0.5062403697996919
# 0.5315987696943066
# 0.02829110038404572
# 0.0398247362486471
# 0.0464289059767694

# %%
cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
seed = 111
#LR_L1 = LogisticRegression(penalty='l1', random_state=seed, solver='saga', max_iter=1e5)
#lsvc = LinearSVC(penalty="l1", dual=False)
anova_filter = SelectKBest(f_classif)
pipe = Pipeline([('scaler', StandardScaler()),
                 ('pca', PCA() ),
                  ('anova_filt', anova_filter),
                 ('classifier', RandomForestClassifier()),
                # ('classifiern', KNeighborsClassifier()),
                ])
Lambda = np.array([])
for i in [1e-1, 1, 1e-2]:
    Lambda = np.append(Lambda, i * np.arange(2, 5, 2))

Lambda

search_space1 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                {'classifier': [LogisticRegression(solver='lbfgs')],
                 'pca__n_components':[2,5,10],
                 'classifier__C': Lambda,
                 
                },
                
                ]




search_space2 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
               
                {'classifier': [RandomForestClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__n_estimators': [ 10,100, 500],
                  # 'classifier__n_neighbors': [3, 7, 11],
                'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space3 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
                
                {'classifier': [DecisionTreeClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__max_depth': [5, 10, None],
                 'classifier__max_features': np.arange(10,40,10)},
                
                ]

search_space4 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [KNeighborsClassifier()],
                 'pca__n_components':[2,5,10],
                 'classifier__n_neighbors': [3, 7, 11],
                 'classifier__weights': ['uniform', 'distance']},
               
                ]

search_space5 = [
                 #{'selector__k': [5, 10, 20, 30]},
                { 'anova_filt__k': [2, 5, 10]},
                #{'SelectFromModel__estimator__C': Lambda},
                {'classifier__max_features': np.arange(10,40,10)},
              
                {'classifier': [LinearSVC(class_weight = 'balanced',  dual=False, random_state = np.random.seed(7), tol=1e-05)],
                 'pca__n_components':[2,5,10],
                 'classifier__C':[ np.arange(0.01,100,10) ],
                 #'classifier__max_features': np.arange(10,40,10)
                 #'classifier__gamma': [0.01, 0.1]
                }
                ]
#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

scoring = {

'accuracy': make_scorer(accuracy_score),

'sensitivity': make_scorer(recall_score),

'specificity': make_scorer(recall_score,pos_label=0)

}

clf1=GridSearchCV(pipe, search_space1, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf2=GridSearchCV(pipe, search_space2, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf3=GridSearchCV(pipe, search_space3, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf4=GridSearchCV(pipe, search_space4, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)
clf5=GridSearchCV(pipe, search_space5, scoring='accuracy', n_jobs=1, cv=cv_inner, refit=True)


#clf = GridSearchCV(pipe, search_space, cv=10, verbose=0)
#clf = clf.fit(X, y)

cv_outer = RepeatedStratifiedKFold(

n_splits=10, n_repeats=1, random_state=0

)

scores1 = cross_validate(clf1, X_groupallschizo, y_groupallschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores2 = cross_validate(clf2, X_groupallschizo, y_groupallschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores3 = cross_validate(clf3, X_groupallschizo, y_groupallschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores4 = cross_validate(clf4, X_groupallschizo, y_groupallschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)
scores5 = cross_validate(clf5, X_groupallschizo, y_groupallschizo, scoring=scoring, cv=cv_outer, n_jobs=-1)


print('Logistic Regression accuracy', mean(scores1['test_accuracy']), 'standard deviation', std(scores1['test_accuracy']))
print('Logistic Regression sensitivity ',mean(scores1['test_sensitivity']), 'standard deviation', std(scores1['test_sensitivity'])  )
print('Logistic Regression specificity',mean(scores1['test_specificity']) , 'standard deviation', std(scores1['test_specificity']))

print('\n')

print('Random Forest Classifier accuracy',mean(scores2['test_accuracy']), 'standard deviation', std(scores2['test_accuracy']))
print('Random Forest Classifier sensitivity ',mean(scores2['test_sensitivity']),'standard deviation', std(scores2['test_sensitivity']))
print('Random Forest Classifier specificity',mean(scores2['test_specificity']),'standard deviation', std(scores2['test_specificity']))

print('\n')
print('Decision Tree Classifier accuracy',mean(scores3['test_accuracy']),'standard deviation', std(scores3['test_accuracy']))
print('Decision Tree Classifier sensitivity',mean(scores3['test_sensitivity']),'standard deviation', std(scores3['test_sensitivity']))
print('Decision Tree Classifier specificity',mean(scores3['test_specificity']),'standard deviation', std(scores3['test_specificity']))
print('\n')

print('KNeighborsClassifier accuracy',mean(scores4['test_accuracy']),'standard deviation', std(scores4['test_accuracy']))
print('KNeighborsClassifier sensitivity',mean(scores4['test_sensitivity']),'standard deviation', std(scores4['test_sensitivity']))
print('KNeighborsClassifier specificity',mean(scores4['test_specificity']),'standard deviation', std(scores4['test_specificity']))

print('\n')
print('SVM accuracy',mean(scores5['test_accuracy']),'standard deviation', std(scores5['test_accuracy']))
print('SVM sensitivity',mean(scores5['test_sensitivity']),'standard deviation', std(scores5['test_sensitivity']))
print('SVM specificity',mean(scores5['test_specificity']),'standard deviation', std(scores5['test_specificity']))
# Out:
# Logistic Regression accuracy 0.5221008070897294 standard deviation 0.017190579524143556
# Logistic Regression sensitivity  0.4892077555213148 standard deviation 0.04244494152802566
# Logistic Regression specificity 0.5545132132320633 standard deviation 0.029044859120728322
#
#
# Random Forest Classifier accuracy 0.5178968191169488 standard deviation 0.024064136743380246
# Random Forest Classifier sensitivity  0.49548664612223925 standard deviation 0.0464788829917506
# Random Forest Classifier specificity 0.5399786579624631 standard deviation 0.06146531811154588
#
#
# Decision Tree Classifier accuracy 0.5094484886849184 standard deviation 0.022420133099001857
# Decision Tree Classifier sensitivity 0.4632318952234207 standard deviation 0.0855331084759539
# Decision Tree Classifier specificity 0.5550530412403489 standard deviation 0.0479881610315821
#
#
# KNeighborsClassifier accuracy 0.5071791422693465 standard deviation 0.025510558974090474
# ...

# %% [markdown]
# ### feature importances for group analysis

# %%
def FeatureImportance(dataframe):
    
    X=dataframe.drop(['label'],axis=1)
    y=dataframe['label']
    X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3, random_state=0)
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    model=RandomForestClassifier()
    model=model.fit(X_train,y_train)
    # get importance
    importance = model.feature_importances_
    sorted_indices = np.argsort(importance)[::-1]
    # summarize feature importance
    for i,v in enumerate(importance):
        print('Feature: %0d, Score: %.5f' % (i,v))
    # plot feature importance
    #plt.bar([x for x in range(len(importance))], importance)
    #plt.bar([col_name for col_name in df_groupall.columns], importance)
    #plt.show()
    
    
    plt.rcParams["figure.figsize"] = (10, 4.5)
    plt.title('Feature Importance')
    plt.bar(range(X_train.shape[1]), importance[sorted_indices], align='center')
    plt.xticks(range(X_train.shape[1]), X.columns[sorted_indices], rotation=90)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### feature importances with normal subject

# %%
FeatureImportance(df_groupall)
# Out:
# Feature: 0, Score: 0.04518
# Feature: 1, Score: 0.04279
# Feature: 2, Score: 0.04203
# Feature: 3, Score: 0.04421
# Feature: 4, Score: 0.04027
# Feature: 5, Score: 0.04361
# Feature: 6, Score: 0.04454
# Feature: 7, Score: 0.04023
# Feature: 8, Score: 0.04263
# Feature: 9, Score: 0.04984
# Feature: 10, Score: 0.05707
# Feature: 11, Score: 0.05391
# Feature: 12, Score: 0.03549
# Feature: 13, Score: 0.03152
# Feature: 14, Score: 0.03255
# Feature: 15, Score: 0.03753
# Feature: 16, Score: 0.03317
# Feature: 17, Score: 0.03812
# Feature: 18, Score: 0.04210
# Feature: 19, Score: 0.03423
# Feature: 20, Score: 0.03620
# Feature: 21, Score: 0.05018
# Feature: 22, Score: 0.04321
# Feature: 23, Score: 0.03940

# %% [markdown]
# ### feature importances with schizophrenia subject

# %%
FeatureImportance(df_groupallschizo)
# Out:
# Feature: 0, Score: 0.04738
# Feature: 1, Score: 0.04524
# Feature: 2, Score: 0.04642
# Feature: 3, Score: 0.04458
# Feature: 4, Score: 0.04272
# Feature: 5, Score: 0.04463
# Feature: 6, Score: 0.04519
# Feature: 7, Score: 0.04282
# Feature: 8, Score: 0.04511
# Feature: 9, Score: 0.04666
# Feature: 10, Score: 0.04790
# Feature: 11, Score: 0.05138
# Feature: 12, Score: 0.03566
# Feature: 13, Score: 0.03223
# Feature: 14, Score: 0.03689
# Feature: 15, Score: 0.03493
# Feature: 16, Score: 0.03603
# Feature: 17, Score: 0.03649
# Feature: 18, Score: 0.04376
# Feature: 19, Score: 0.03528
# Feature: 20, Score: 0.03440
# Feature: 21, Score: 0.04211
# Feature: 22, Score: 0.04064
# Feature: 23, Score: 0.04152

# %% [markdown]
# ## old

# %%
X = df.loc[:, ~df.columns.isin(['label'])]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, test_size=0.2, random_state=15)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (56, 24)
# (16, 24)
# (7, 24)
# (56,)
# (16,)
# (7,)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = pd.DataFrame(sc_X.fit_transform(X_train))
X_test = pd.DataFrame(sc_X.transform(X_test))

# %%
warnings.filterwarnings('ignore')
# Baseline - comparing model accuracy using all features across classifiers 
classifiers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    KNeighborsClassifier(),
    SVC(kernel="linear"),
    GaussianNB(),
    LogisticRegression()
    ]


# Naive Train Accuracy
algo = []
scores = []
for clf in classifiers:
    algo.append(clf.__class__.__name__)
    scores.append(cross_val_score(clf,X_train,y_train, cv=5).mean())
warnings.filterwarnings('ignore')
Naivescore_df_Train = pd.DataFrame({'Algorithm': algo, 'Score': scores}).set_index('Algorithm')


# Naive Test Accuracy_train

algo = []
scores = []

for clf in classifiers:
    clf = clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    algo.append(clf.__class__.__name__)
    scores.append(accuracy_score(y_pred, y_test))
warnings.filterwarnings('ignore')
Naivescore_df_Test  = pd.DataFrame({'Algorithm': algo, 'Score': scores}).set_index('Algorithm')

# Bar plot between Train and Test Accuracy
fig = plt.figure(figsize=(5,5)) # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as a
width = .3

Naivescore_df_Train.Score.plot(kind='bar',color='green',ax=ax,width=width, position=0)
Naivescore_df_Test.Score.plot(kind='bar',color='red', ax=ax2,width = width,position=1)

print('Train accuracy',Naivescore_df_Train)
print('Test accuracy',Naivescore_df_Test)

ax.grid(None, axis=1)
ax2.grid(None)

ax.set_ylabel('Train')
ax2.set_ylabel('Test')

ax.set_xlim(-1,7)
plt.show()
# Out:
# Train accuracy                            Score
# Algorithm
# DecisionTreeClassifier  0.642424
# RandomForestClassifier  0.730303
# KNeighborsClassifier    0.731818
# SVC                     0.662121
# GaussianNB              0.624242
# LogisticRegression      0.678788
# Test accuracy                          Score
# Algorithm
# DecisionTreeClassifier  0.5625
# RandomForestClassifier  0.5000
# KNeighborsClassifier    0.3125
# SVC                     0.5000
# GaussianNB              0.5000
# LogisticRegression      0.5000

# %%
X=df.loc[:,~df.columns.isin(['label'])]
y=df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, test_size=0.2, random_state=15)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (56, 24)
# (16, 24)
# (7, 24)
# (56,)
# (16,)
# (7,)

# %% [markdown]
#  ### new

# %%
def logisticregression(): 
    from sklearn import metrics
    log_reg = LogisticRegression(random_state=10, solver = 'lbfgs')
    #log_reg=LogisticRegression(random_state=0, penalty='l2')
    log_reg.fit(X_train, y_train)
    y_pred = log_reg.predict(X_train)

    # predict_proba - Probability estimates
    pred_proba = log_reg.predict_proba(X_train)
    print("The Training Accuracy is: ", log_reg.score(X_train, y_train))
    print("The Testing Accuracy is: ", log_reg.score(X_test, y_test))
    print(classification_report(y_train, y_pred))
    print("Confusion matrix is: ")
    cm = confusion_matrix(y_train, y_pred)
    cm_norm = cm / cm.sum(axis=1).reshape(-1,1)
    

    y_pred_proba = log_reg.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.show()
    
    return cm,log_reg.score(X_test, y_test)

def logisticregression2():
    from sklearn import metrics
    logreg = LogisticRegression()
    # fit the model with data
    logreg.fit(X_train,y_train)
    y_pred=logreg.predict(X_test)
    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
    print("Precision:",metrics.precision_score(y_test, y_pred))
    print("Recall:",metrics.recall_score(y_test, y_pred))
    cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
    
    y_pred_proba = logreg.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.show()
    
    return cnf_matrix,metrics.accuracy_score(y_test, y_pred)
    
    

def svm(): 
    #Import svm model
    from sklearn import metrics
    from sklearn import svm

    #Create a svm Classifier
    clf = svm.SVC(kernel='linear' , probability=True) # Linear Kernel

    #Train the model using the training sets
    clf.fit(X_train, y_train)

    #Predict the response for test dataset
    y_pred = clf.predict(X_test) 
    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
    print("Precision:",metrics.precision_score(y_test, y_pred))
    print("Recall:",metrics.recall_score(y_test, y_pred))
    
    y_pred_proba = clf.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.show()
    return metrics.accuracy_score(y_test, y_pred)
    
    
def randomforest(): 
    from sklearn.ensemble import RandomForestClassifier
    from sklearn import metrics
    #Create a Gaussian Classifier
    clf=RandomForestClassifier(n_estimators=100)
    #Train the model using the training sets y_pred=clf.predict(X_test)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    # Model Accuracy, how often is the classifier correct?
    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
    
    y_pred_proba = clf.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.show()
    return metrics.accuracy_score(y_test, y_pred)
    

def naivebayes(): 
    from sklearn.naive_bayes import GaussianNB
    model = GaussianNB()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy=metrics.accuracy_score(y_test,y_pred )
    
    y_pred_proba = model.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.show()
    
    return accuracy

def decisiontreeclassifier(): 
    clf=DecisionTreeClassifier()
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    print("Accuracy:",metrics.accuracy_score(y_test,y_pred ))
    
    y_pred_proba = clf.predict_proba(X_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
    plt.legend(loc=4)
    plt.show()
    return metrics.accuracy_score(y_test,y_pred )

# %% [markdown]
# ### feature extraction using correlation

# %%
corr = df.corr()

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False
selected_columns = df.columns[columns]
datan = df[selected_columns]

# %%
X = datan.loc[:, ~datan.columns.isin(['label'])]
y=df[['label']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, test_size=0.2, random_state=15)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (56, 22)
# (16, 22)
# (7, 22)
# (56, 1)
# (16, 1)
# (7, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = pd.DataFrame(sc_X.fit_transform(X_train))
X_test = pd.DataFrame(sc_X.transform(X_test))

# %% [markdown]
# #### logistic regression

# %%
cm,acc_logisticregression=logisticregression()
cm
# Out:
# The Training Accuracy is:  0.8392857142857143
# The Testing Accuracy is:  0.5
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        29
#            1       0.82      0.85      0.84        27
#
#     accuracy                           0.84        56
#    macro avg       0.84      0.84      0.84        56
# weighted avg       0.84      0.84      0.84        56
#
# Confusion matrix is:
# array([[24,  5],
#        [ 4, 23]])

# %%
cm2,acc_logisticregression2=logisticregression2()
cm2
# Out:
# Accuracy: 0.5
# Precision: 0.75
# Recall: 0.3
# array([[5, 1],
#        [7, 3]])

# %% [markdown]
# #### SVM

# %%
acc_svm=svm()
# Out:
# Accuracy: 0.5
# Precision: 0.75
# Recall: 0.3

# %%
acc_naivebayes=naivebayes()
acc_naivebayes
# Out:
# 0.5

# %%
acc_decisiontreeclassifier=decisiontreeclassifier()
# Out:
# Accuracy: 0.3125

# %%
acc_randomforest=randomforest()
# Out:
# Accuracy: 0.625

# %%
results = pd.DataFrame([['Correlation', acc_logisticregression,acc_svm,acc_naivebayes,acc_decisiontreeclassifier,acc_randomforest]],columns=['Feature selection ', 'Accuracy logistic regression', 'Accuracy SVM','Accuracy naivebayes','Accuracy decisiontreeclassifier','Accuracy randomforest'])
results
# Out:
#   Feature selection   Accuracy logistic regression  Accuracy SVM  \
# 0        Correlation                           0.5           0.5
#
#    Accuracy naivebayes  Accuracy decisiontreeclassifier  Accuracy randomforest
# 0                  0.5                           0.3125                  0.625

# %% [markdown]
# ### model for feature selection

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
Xn = df.loc[:, ~df.columns.isin(['label'])]
y = df['label']

# %%
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(Xn, y)
model = SelectFromModel(lsvc, prefit=True)
X_new = model.transform(Xn)
X_new.shape
# Out:
# (79, 7)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, train_size = 0.8, test_size=0.2, random_state=15)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (56, 7)
# (16, 7)
# (7, 7)
# (56,)
# (16,)
# (7,)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = pd.DataFrame(sc_X.fit_transform(X_train))
X_test = pd.DataFrame(sc_X.transform(X_test))

# %% [markdown]
# #### logistic regression

# %%
cm,acc_logisticregression=logisticregression()
cm
# Out:
# The Training Accuracy is:  0.6964285714285714
# The Testing Accuracy is:  0.6875
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72        29
#            1       0.71      0.63      0.67        27
#
#     accuracy                           0.70        56
#    macro avg       0.70      0.69      0.69        56
# weighted avg       0.70      0.70      0.69        56
#
# Confusion matrix is:
# array([[22,  7],
#        [10, 17]])

# %% [markdown]
# #### SVM

# %%
acc_svm=svm()
# Out:
# Accuracy: 0.5625
# Precision: 0.8
# Recall: 0.4

# %% [markdown]
# #### naive bayes

# %%
acc_naivebayes=naivebayes()
acc_naivebayes
# Out:
# 0.875

# %% [markdown]
# #### decision tree classifier

# %%
acc_decisiontreeclassifier=decisiontreeclassifier()
# Out:
# Accuracy: 0.5

# %%
acc_randomforest=randomforest()
# Out:
# Accuracy: 0.5

# %%
model_results = pd.DataFrame([['model for feature selection', acc_logisticregression,acc_svm,acc_naivebayes,acc_decisiontreeclassifier,acc_randomforest]],columns=['Feature selection ', 'Accuracy logistic regression', 'Accuracy SVM','Accuracy naivebayes','Accuracy decisiontreeclassifier','Accuracy randomforest'])


results = results.append(model_results, ignore_index = True)
results
# Out:
#             Feature selection   Accuracy logistic regression  Accuracy SVM  \
# 0                  Correlation                        0.5000        0.5000
# 1  model for feature selection                        0.6875        0.5625
#
#    Accuracy naivebayes  Accuracy decisiontreeclassifier  Accuracy randomforest
# 0                0.500                           0.3125                  0.625
# 1                0.875                           0.5000                  0.500

# %% [markdown]
# ### with selectKBest selection method

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import chi2
Xn2 = df.loc[:, ~df.columns.isin(['label'])]
#X_clf_new=SelectKBest(score_func=chi2,k=2).fit_transform(X_clf,y_clf)
X_selected=SelectKBest(score_func=chi2,k=2).fit_transform(Xn2,y)
# apply feature selectio
print(X_selected.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-2d0e195e2d00> in <module>()
#       4 Xn2 = df.loc[:, ~df.columns.isin(['label'])]
#       5 #X_clf_new=SelectKBest(score_func=chi2,k=2).fit_transform(X_clf,y_clf)
# ----> 6 X_selected=SelectKBest(score_func=chi2,k=2).fit_transform(Xn2,y)
#       7 # apply feature selectio
#       8 print(X_selected.shape)
#
# /home/vakpawar/.local/lib/python3.5/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
# --> 574             return self.fit(X, y, **fit_params).transform(X)
#     575
#     576
#
# /home/vakpawar/.local/lib/python3.5/site-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     347
#     348         self._check_params(X, y)
# ...

# %% [markdown]
# ### Tree-based feature selection

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

Xn5 = df.loc[:, ~df.columns.isin(['label'])]
clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(Xn5, y)
clf.feature_importances_
# Out:
# array([0.11410075, 0.02891006, 0.04185932, 0.04345804, 0.03381294,
#        0.03348563, 0.03144757, 0.02828617, 0.06157038, 0.03506448,
#        0.05369851, 0.03602485, 0.02678742, 0.02852173, 0.02810527,
#        0.02993993, 0.03591201, 0.04788593, 0.07654506, 0.0256385 ,
#        0.04390545, 0.04287382, 0.03638762, 0.03577856])

# %%
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(Xn5)
X_new.shape
# Out:
# (79, 9)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, train_size = 0.8, test_size=0.2, random_state=15)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (56, 9)
# (16, 9)
# (7, 9)
# (56,)
# (16,)
# (7,)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = pd.DataFrame(sc_X.fit_transform(X_train))
X_test = pd.DataFrame(sc_X.transform(X_test))

# %% [markdown]
# #### logistic regression

# %%
cm,acc_logisticregression=logisticregression()
cm
# Out:
# The Training Accuracy is:  0.8035714285714286
# The Testing Accuracy is:  0.5
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81        29
#            1       0.79      0.81      0.80        27
#
#     accuracy                           0.80        56
#    macro avg       0.80      0.80      0.80        56
# weighted avg       0.80      0.80      0.80        56
#
# Confusion matrix is:
# array([[23,  6],
#        [ 5, 22]])

# %% [markdown]
# #### SVM

# %%
acc_svm=svm()
# Out:
# Accuracy: 0.5
# Precision: 0.75
# Recall: 0.3

# %% [markdown]
# #### naive bayes

# %%
acc_naivebayes=naivebayes()
acc_naivebayes
# Out:
# 0.5625

# %% [markdown]
# #### decision tree

# %%
acc_decisiontreeclassifier=decisiontreeclassifier()
# Out:
# Accuracy: 0.5625

# %%
acc_randomforest=randomforest()
# Out:
# Accuracy: 0.5625

# %%
model_results_treebased = pd.DataFrame([['tree based feature selection', acc_logisticregression,acc_svm,acc_naivebayes,acc_decisiontreeclassifier,acc_randomforest]],columns=['Feature selection ', 'Accuracy logistic regression', 'Accuracy SVM','Accuracy naivebayes','Accuracy decisiontreeclassifier','Accuracy randomforest'])


results = results.append(model_results_treebased, ignore_index = True)
results
# Out:
#              Feature selection   Accuracy logistic regression  Accuracy SVM  \
# 0                   Correlation                        0.5000        0.5000
# 1   model for feature selection                        0.6875        0.5625
# 2  tree based feature selection                        0.5000        0.5000
#
#    Accuracy naivebayes  Accuracy decisiontreeclassifier  Accuracy randomforest
# 0               0.5000                           0.3125                 0.6250
# 1               0.8750                           0.5000                 0.5000
# 2               0.5625                           0.5625                 0.5625

# %% [markdown]
# ### feature selection with variance thresold

# %%
from sklearn.feature_selection import VarianceThreshold
X3 = df.loc[:, ~df.columns.isin(['label'])]
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
X_new2=sel.fit_transform(X3)

# %%
X_new2.shape
# Out:
# (79, 12)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new2, y, train_size = 0.8, test_size=0.2, random_state=15)
# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (56, 12)
# (16, 12)
# (7, 12)
# (56,)
# (16,)
# (7,)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = pd.DataFrame(sc_X.fit_transform(X_train))
X_test = pd.DataFrame(sc_X.transform(X_test))

# %% [markdown]
# #### logistic regression

# %%
cm,acc_logisticregression=logisticregression()
cm
# Out:
# The Training Accuracy is:  0.6607142857142857
# The Testing Accuracy is:  0.6875
#               precision    recall  f1-score   support
#
#            0       0.65      0.76      0.70        29
#            1       0.68      0.56      0.61        27
#
#     accuracy                           0.66        56
#    macro avg       0.66      0.66      0.66        56
# weighted avg       0.66      0.66      0.66        56
#
# Confusion matrix is:
# array([[22,  7],
#        [12, 15]])

# %% [markdown]
# #### SVM

# %%
acc_svm=svm()
# Out:
# Accuracy: 0.5
# Precision: 0.6666666666666666
# Recall: 0.4

# %% [markdown]
# #### naive bayes

# %%
acc_naivebayes=naivebayes()
acc_naivebayes
# Out:
# 0.8125

# %% [markdown]
# #### decision tree classifier

# %%
acc_decisiontreeclassifier=decisiontreeclassifier()
# Out:
# Accuracy: 0.5625

# %%
acc_randomforest=randomforest()
# Out:
# Accuracy: 0.6875

# %%
model_results_variance = pd.DataFrame([['model for variance thresold', acc_logisticregression,acc_svm,acc_naivebayes,acc_decisiontreeclassifier,acc_randomforest]],columns=['Feature selection ', 'Accuracy logistic regression', 'Accuracy SVM','Accuracy naivebayes','Accuracy decisiontreeclassifier','Accuracy randomforest'])


results = results.append(model_results_variance, ignore_index = True)
results
# Out:
#              Feature selection   Accuracy logistic regression  Accuracy SVM  \
# 0                   Correlation                        0.5000        0.5000
# 1   model for feature selection                        0.6875        0.5625
# 2  tree based feature selection                        0.5000        0.5000
# 3   model for variance thresold                        0.6875        0.5000
#
#    Accuracy naivebayes  Accuracy decisiontreeclassifier  Accuracy randomforest
# 0               0.5000                           0.3125                 0.6250
# 1               0.8750                           0.5000                 0.5000
# 2               0.5625                           0.5625                 0.5625
# 3               0.8125                           0.5625                 0.6875

# %% [markdown]
# ### RFE

# %% [markdown]
# ### Decision Tree Classifier

# %%
X_rfe = df.loc[:, ~df.columns.isin(['label'])]
rfe = RFECV(estimator=DecisionTreeClassifier())
model = DecisionTreeClassifier()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_rfe, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
accDecisionTree=mean(n_scores)
print(accDecisionTree)
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# 0.6589285714285715
# Accuracy: 0.659 (0.173)

# %% [markdown]
# ### LogisticRegression Classifier

# %%
X_rfe = df.loc[:, ~df.columns.isin(['label'])]
rfe = RFECV(estimator=LogisticRegression())
model = LogisticRegression()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_rfe, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
accLogisticRegression=mean(n_scores)
print(accLogisticRegression)
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# 0.5970238095238096
# Accuracy: 0.597 (0.131)

# %% [markdown]
# ### Random Forest Classifier Classifier

# %%
X_rfe = df.loc[:, ~df.columns.isin(['label'])]
rfe = RFECV(estimator=RandomForestClassifier())
model = RandomForestClassifier()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_rfe, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
accRandomForest=mean(n_scores)
print(accRandomForest)
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# 0.6035714285714285
# Accuracy: 0.604 (0.160)

# %%
from sklearn.svm import SVC
X_rfe = df.loc[:, ~df.columns.isin(['label'])]
model = SVC(kernel="linear", C=1)
rfe = RFE(estimator=model, n_features_to_select=1, step=1)
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_rfe, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
accSVM=mean(n_scores)
print(accSVM)
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# 0.5214285714285715
# Accuracy: 0.521 (0.064)

# %%
model_results_rfe = pd.DataFrame([['Recursive feature elimination', accLogisticRegression,accSVM,accDecisionTree,accRandomForest]],columns=['Feature selection ', 'Accuracy logistic regression', 'Accuracy SVM','Accuracy decisiontreeclassifier','Accuracy randomforest'])

model_results_rfe
#results = results.append(model_results_rfe, ignore_index = True)
#results
# Out:
#               Feature selection   Accuracy logistic regression  Accuracy SVM  \
# 0  Recursive feature elimination                      0.597024      0.521429
#
#    Accuracy decisiontreeclassifier  Accuracy randomforest
# 0                         0.658929               0.603571

# %% [markdown]
# # old

# %% [markdown]
# ###  Random forest

# %%
X = df.loc[:, ~df.columns.isin(['label'])]
y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
randomforest()
# Out:
# Accuracy: 0.4583333333333333

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5

# %% [markdown]
# ###  feature importance

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
import pandas as pd
feature_imp = pd.Series(clf.feature_importances_,index=list(X.columns)).sort_values(ascending=False)
feature_imp
# Out:
# max_amppz2        0.079221
# max_ampfz2        0.064573
# min_ampfz3        0.062539
# latency_mincz3    0.056347
# min_ampcz3        0.049618
# min_amppz3        0.048204
# latency_mincz1    0.047902
# max_ampcz2        0.047181
# max_ampfz4        0.044906
# latency_minpz1    0.044584
# max_ampcz4        0.043082
# latency_maxpz2    0.040044
# min_ampfz1        0.038854
# latency_minfz1    0.036243
# latency_minfz3    0.035172
# latency_maxpz4    0.032443
# latency_maxfz2    0.031504
# latency_maxcz2    0.030984
# min_amppz1        0.030595
# min_ampcz1        0.030320
# latency_minpz3    0.028595
# latency_maxcz4    0.026131
# max_amppz4        0.025823
# latency_maxfz4    0.025134
# dtype: float64

# %%
features= feature_imp[feature_imp>0]
features.index
# Out:
# Index(['max_amppz2', 'max_ampfz2', 'min_ampfz3', 'latency_mincz3',
#        'min_ampcz3', 'min_amppz3', 'latency_mincz1', 'max_ampcz2',
#        'max_ampfz4', 'latency_minpz1', 'max_ampcz4', 'latency_maxpz2',
#        'min_ampfz1', 'latency_minfz1', 'latency_minfz3', 'latency_maxpz4',
#        'latency_maxfz2', 'latency_maxcz2', 'min_amppz1', 'min_ampcz1',
#        'latency_minpz3', 'latency_maxcz4', 'max_amppz4', 'latency_maxfz4'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['latency_maxcz2', 'latency_maxcz4', 'latency_maxfz2', 'latency_maxfz4',
#        'latency_maxpz2', 'latency_maxpz4', 'latency_mincz1', 'latency_mincz3',
#        'latency_minfz1', 'latency_minfz3', 'latency_minpz1', 'latency_minpz3',
#        'max_ampcz2', 'max_ampcz4', 'max_ampfz2', 'max_ampfz4', 'max_amppz2',
#        'max_amppz4', 'min_ampcz1', 'min_ampcz3', 'min_ampfz1', 'min_ampfz3',
#        'min_amppz1', 'min_amppz3'],
#       dtype='object')

# %%
cols = features.index
X_new=X[cols]
X_new
# Out:
#     max_amppz2  max_ampfz2  min_ampfz3  latency_mincz3  min_ampcz3  \
# 0    18.431763   22.645699   -2.530988        0.272656    9.617881
# 1    35.594460   14.307274   14.307274        0.186719   21.298868
# 2    13.445862   33.639877   15.683022        0.276562   19.907953
# 3    47.631283   62.319523   42.275520        0.276562   23.624670
# 4   -36.040966  -48.023693  -48.023693        0.210156  -40.015442
# 5    16.425827   -6.827663  -22.772844        0.233594   -6.427661
# 6    39.040798   23.367960   21.111507        0.260937   31.057198
# 7    29.677572   21.696728   17.008928        0.260937   20.638721
# 8     4.653949   12.657302   12.657302        0.284375   -9.120334
# 9    23.946779   67.619743   67.619743        0.198437   45.216702
# 10   36.348751   37.935158   37.935158        0.233594   16.667763
# 11   36.542301   -4.240356  -22.194696        0.249219   14.155570
# 12   33.405247   30.647753   30.647753        0.151562   38.594147
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.70, random_state=5) # 70% training and 30% test

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

# prediction on test set
y_pred=clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5892857142857143
